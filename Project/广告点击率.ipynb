# %% [markdown]
# ## 广告点击率预测
# 这个项目的主要的目的是通过给定的广告信息和用户信息来预测一个广告被点击与否。 如果广告有很大概率被点击就展示广告，如果概率低，就不展示。 因为如果广告没有被点击，对双方（广告主、平台）来讲都没有好处。所以预测这个概率非常重要，也是此项目的目标。

# %% [markdown]
# 在这个项目中，你需要完成以下的任务：
# - ``数据的读取和理解``: 把给定的.csv文件读入到内存，并通过pandas做数据方面的统计以及可视化来更深入地理解数据。
# - ``特征构造``: 从原始特征中衍生出一些新的特征，这部分在机器学习领域也是很重要的工作。
# - ``特征的转化``: 特征一般分为连续型(continuous)和类别型（categorical), 需要分别做不同的处理。
# - ``特征选择``: 从已有的特征中选择合适的特征，这部分也是很多项目中必不可少的部分。
# - ``模型训练与评估``: 通过交叉验证方式来训练模型，这里需要涉及到网格搜索等技术。
#
#
# 你需要完成标记为`TODO`的部分。
#
# 另外，提交作业时候的注意点：
# > 1. 不要试图去创建另外一个.ipynb文件，所有的程序需要在`starter_code.ipynb`里面实现。很多的模块已经帮你写好，不要试图去修改已经定义好的函数以及名字。 当然，自己可以按需求来创建新的函数。但一定要按照给定的框架来写程序，不然判作业的时候会出现很多问题。
# > 2. 上传作业的时候把整个文件解压成.zip文件（不要.rar格式），请不要上传图片文件和数据文件，其他的都需要上传包括`README.md`。
# > 3. 确保程序能够正常运行，我们支持的环境是`Python 3`,  千万不要使用`Python 2`
# > 4. 上传前一定要确保完整性，批改过一次的作业我们不会再重新批改，会作为最终的分数来对待。
# > 5. 作业可以讨论，但请自己完成。让我们一起遵守贪心学院的`honor code`。
#
# 好了，我们开始吧！
#
# > ``在提交的.zip文件中请不要包含train.csv文件！！！``

# %% [markdown]
# ### 1. 数据读取和理解
# 对于``.CSV``的文件，我们一般使用``pandas``工具来读取，读取之后的数据会存放在``dataframe``中。在此项目中，我们使用的是``kaggle``的一个竞赛数据，具体官网地址为：https://www.kaggle.com/c/avazu-ctr-prediction 。 训练和测试数据分别为``train.csv``和``test.csv``。 官网提供的数据比较大，压缩之后的已经达到1G以上。 为了确保让所有人可以在本机上无障碍去调模型，在此项目中，我们特意去采样了一部分数据。 采样的规则为：从``train.csv``文件中读取头``400000``个样本，并重命名为``train_subset.csv``。 之后在这个数据的基础上我们会进一步分为训练集和测试集。所以解压完.zip文件后会发现只有一个``train_subset.csv``文件。
#
# 项目中请``务必要使用``我们提供的样本(当然，你感兴趣也可以在原始样本里尝试，但提交作业时代码一定要基于我们给定的）。 这里给一个小提示： 如果你想在某一个``.csv``文件中只提取头``1000``个样本，在``linux``或者``os``下可以使用如下命令：``head -n1000 train.csv > train_subset.csv``, 意思就是从``train.csv``中提取头``1000``个样本，并存放在``train_subset.csv``中。 为了以后更好的做数据方面的处理，这些基本的命令建议大家都掌握一下。
#
# #### 学习资料推荐 ####
# - 如果对``pandas``比较生疏，或者之前没有使用过，请耐心看这份文档，帮助你马上上手：https://pandas.pydata.org/pandas-docs/stable/getting_started/10min.html
# - 如果对``numpy``比较生疏，或者之前没有接触过，请耐心看这两份文档，很实用： http://jalammar.github.io/visual-numpy/         http://cs231n.github.io/python-numpy-tutorial/
#
# 这些文档足够让你上手``numpy``和``pandas``

# %% [markdown]
# ### 1.1 数据的读取

# %%
# 导入基本的库，每个项目的必备
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# 设置matplotlib的模式
# %matplotlib inline

# 设置matplot的样式
import matplotlib
matplotlib.style.use('ggplot')

# %%
# 通过pandas读取.csv文件，并展示头几个样本。
data_df = pd.read_csv('train_subset.csv')
data_df.head()
# Out:
#              id  click      hour    C1  banner_pos   site_id site_domain  \
# 0  1.000009e+18      0  14102100  1005           0  1fbe01fe    f3845767
# 1  1.000017e+19      0  14102100  1005           0  1fbe01fe    f3845767
# 2  1.000037e+19      0  14102100  1005           0  1fbe01fe    f3845767
# 3  1.000064e+19      0  14102100  1005           0  1fbe01fe    f3845767
# 4  1.000068e+19      0  14102100  1005           1  fe8cc448    9166c161
#
#   site_category    app_id app_domain  ... device_type device_conn_type    C14  \
# 0      28905ebd  ecad2386   7801e8d9  ...           1                2  15706
# 1      28905ebd  ecad2386   7801e8d9  ...           1                0  15704
# 2      28905ebd  ecad2386   7801e8d9  ...           1                0  15704
# 3      28905ebd  ecad2386   7801e8d9  ...           1                0  15706
# 4      0569f928  ecad2386   7801e8d9  ...           1                0  18993
#
#    C15  C16   C17  C18  C19     C20  C21
# 0  320   50  1722    0   35      -1   79
# 1  320   50  1722    0   35  100084   79
# 2  320   50  1722    0   35  100084   79
# 3  320   50  1722    0   35  100084   79
# 4  320   50  2161    0   35      -1  157
#
# [5 rows x 24 columns]

# %% [markdown]
# > ``问题1（TODO）：`` 在上面的数据中有一个特征叫作``hour``, 是时间的特征，但这个值有些看不懂... 这部分需要通过pandas来做处理。把这个数转换成具体时间的格式。请把这个特征格式化成``%y%m%d%H``形式。格式化完之后请覆盖掉原来的特征。提示： 使用 ``pd.to_datetime``函数，然后指定需要格式化的特征和格式化的样式。

# %%
# TODO 把hour特征格式化成 '%y%m%d%H'形式。
temp = pd.to_datetime(data_df['hour'], format='%y%m%d%H')
data_df['hour'] = temp

# %%
# 重新打印一下是否有改变
data_df.head()
# Out:
#              id  click       hour    C1  banner_pos   site_id site_domain  \
# 0  1.000009e+18      0 2014-10-21  1005           0  1fbe01fe    f3845767
# 1  1.000017e+19      0 2014-10-21  1005           0  1fbe01fe    f3845767
# 2  1.000037e+19      0 2014-10-21  1005           0  1fbe01fe    f3845767
# 3  1.000064e+19      0 2014-10-21  1005           0  1fbe01fe    f3845767
# 4  1.000068e+19      0 2014-10-21  1005           1  fe8cc448    9166c161
#
#   site_category    app_id app_domain  ... device_type device_conn_type    C14  \
# 0      28905ebd  ecad2386   7801e8d9  ...           1                2  15706
# 1      28905ebd  ecad2386   7801e8d9  ...           1                0  15704
# 2      28905ebd  ecad2386   7801e8d9  ...           1                0  15704
# 3      28905ebd  ecad2386   7801e8d9  ...           1                0  15706
# 4      0569f928  ecad2386   7801e8d9  ...           1                0  18993
#
#    C15  C16   C17  C18  C19     C20  C21
# 0  320   50  1722    0   35      -1   79
# 1  320   50  1722    0   35  100084   79
# 2  320   50  1722    0   35  100084   79
# 3  320   50  1722    0   35  100084   79
# 4  320   50  2161    0   35      -1  157
#
# [5 rows x 24 columns]

# %%
# 由于特征个数比较多，有些特征被隐藏掉了（表示成了...)， 为了把所有特征全部看到，可以分两次来展示：
data_df.iloc[:, :12].head()
# Out:
#              id  click       hour    C1  banner_pos   site_id site_domain  \
# 0  1.000009e+18      0 2014-10-21  1005           0  1fbe01fe    f3845767
# 1  1.000017e+19      0 2014-10-21  1005           0  1fbe01fe    f3845767
# 2  1.000037e+19      0 2014-10-21  1005           0  1fbe01fe    f3845767
# 3  1.000064e+19      0 2014-10-21  1005           0  1fbe01fe    f3845767
# 4  1.000068e+19      0 2014-10-21  1005           1  fe8cc448    9166c161
#
#   site_category    app_id app_domain app_category device_id
# 0      28905ebd  ecad2386   7801e8d9     07d7df22  a99f214a
# 1      28905ebd  ecad2386   7801e8d9     07d7df22  a99f214a
# 2      28905ebd  ecad2386   7801e8d9     07d7df22  a99f214a
# 3      28905ebd  ecad2386   7801e8d9     07d7df22  a99f214a
# 4      0569f928  ecad2386   7801e8d9     07d7df22  a99f214a

# %%
data_df.iloc[:, 12:].head()
# Out:
#   device_ip device_model  device_type  device_conn_type    C14  C15  C16  \
# 0  ddd2926e     44956a24            1                 2  15706  320   50
# 1  96809ac8     711ee120            1                 0  15704  320   50
# 2  b3cf8def     8a4875bd            1                 0  15704  320   50
# 3  e8275b8f     6332421a            1                 0  15706  320   50
# 4  9644d0bf     779d90c2            1                 0  18993  320   50
#
#     C17  C18  C19     C20  C21
# 0  1722    0   35      -1   79
# 1  1722    0   35  100084   79
# 2  1722    0   35  100084   79
# 3  1722    0   35  100084   79
# 4  2161    0   35      -1  157

# %% [markdown]
# 从上述数据中，你会发现大量的特征为类别型特征，而且很多特征已经被编码成看不懂的字符串（这些都是为了不公开用户数据），但即便如此，我们也可以把它们直接看成是类别型特征（categorical featuer）。

# %%
# 查看一下每一个特征的类型以及是否存在null
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 399999 entries, 0 to 399998
# Data columns (total 24 columns):
# id                  399999 non-null float64
# click               399999 non-null int64
# hour                399999 non-null datetime64[ns]
# C1                  399999 non-null int64
# banner_pos          399999 non-null int64
# site_id             399999 non-null object
# site_domain         399999 non-null object
# site_category       399999 non-null object
# app_id              399999 non-null object
# app_domain          399999 non-null object
# app_category        399999 non-null object
# device_id           399999 non-null object
# device_ip           399999 non-null object
# device_model        399999 non-null object
# device_type         399999 non-null int64
# device_conn_type    399999 non-null int64
# C14                 399999 non-null int64
# C15                 399999 non-null int64
# C16                 399999 non-null int64
# C17                 399999 non-null int64
# C18                 399999 non-null int64
# C19                 399999 non-null int64
# C20                 399999 non-null int64
# C21                 399999 non-null int64
# dtypes: datetime64[ns](1), float64(1), int64(13), object(9)
# memory usage: 73.2+ MB

# %% [markdown]
# ### 1.2 数据的理解

# %% [markdown]
# #### ``id``特征 ####
# 我们是否需要这个特征？ 应该如何判断？ 如果发现不需要此特征就可以从data_df中删掉了。
# > ``问题2（TODO）`` 1. 请判断这个特征有没有价值  2. 如果没有价值就把它从data_df中删掉。 提示： 如果对于每一个样本，``id``都是不一样的，那显然是无用的特征。

# %%
# TODO： 请实现上述的逻辑
for item in data_df:
    df_temp_num = data_df[item].nunique()
    if df_temp_num==len(data_df.index):
        data_df.drop(item,  axis=1, inplace=True)
        print(item + ' is removed')
# Out:
# id is removed

# %% [markdown]
# #### ``click``标签(label) ####
# 对标签分布的理解是必不可少的，因为这直接跟样本不平衡相关。
# > ``问题3（TODO）``: 对于``data_df``, 请输出正样本和负样本各自的比例。

# %%
# TODO： 输出正样本的负样本各自的比例
df_click = data_df['click'].value_counts()
#print(df_click.index)
for i in df_click.index:
    print(str(i)+': '+str(df_click[i]/len(data_df)))
# Out:
# 0: 0.8341095852739632
# 1: 0.16589041472603683

# %% [markdown]
# 通过上述的数据，可以很容易看出被点击的次数要远小于没有被点击的次数。所以这个数据是不平衡的数据。但这个不平衡还没有那么严重。其实不平衡严重时，负样本和正样本比例有可能1000：1， 甚至更悬殊。 由于样本的不平衡，使用准确率是不明智的，所以评估指标我们选用``F1-score``. 如果对这部分不熟，请看第7章的视频。

# %% [markdown]
# #### ``hour``特征 ####
# 时间特征有可能对我们帮助，比如是否凌晨点击率要低于早上的，是否早上的要低于下午的？ 从直观上理解其实是有帮助的。 但由于在这个项目中，我们只提取了前40万个样本，有可能时间上的差别不大（我们要知道一个大的平台，仅仅1分钟就可以收集到数十万到几百万以上的样本）。 但是，不管怎样，打印一下``hour``特征相关的信息看看：

# %%
data_df.hour.describe()
# Out:
# count                  399999
# unique                      3
# top       2014-10-21 02:00:00
# freq                   143551
# first     2014-10-21 00:00:00
# last      2014-10-21 02:00:00
# Name: hour, dtype: object

# %% [markdown]
# 其实从上述的结果中可以看到，时间的区间为10-21的00点到10-21的02点，也就是2个小时的间隔。所以在使用这个特征的时候，可以把小时的特征提取出来，因为日期都是一样的（这部分没价值）。

# %% [markdown]
# #### ``banner_pos``特征 ####
# 这是广告投放的位置，从直观上来看对广告点击的结果影响比较大，所以做一下可视化的分析并更好地理解这个特征。首先来看一下``banner_pos``的取值范围。

# %%
data_df['banner_pos'].unique()
# Out:
# array([0, 1, 4, 5, 2, 7], dtype=int64)

# %% [markdown]
# 从这个结果里可以看出，它的范围是0-7， 但中间不包含3和6， 有可能是我们的训练数据不全。 对于这些数据请不要理所当然地理解为它表示的是具体的位置信息，比如1代表最前面的位置... 因为我们也不知道它的编码规则是怎么样的。但不管怎样，我们可以通过可视化方式来大概了解一下每一个位置对点击率的影响。
#
# > ``问题4（TODO）``: 通过可视化方式来展示每一个位置上的样本总数以及其中被点击和没有被点击的样本个数。需要得到如下的这样的一幅图：
# <img src="sample_img1.png" alt="drawing" width="300"/>

# %%
# TODO: 输出类似于上述这幅图
click_count = data_df.groupby(['banner_pos'])['click'].value_counts()
click_count = click_count.to_frame()['click']
'''Convert Series to DataFrame'''
print(click_count)

banner_pos_idx, v1, v2 = [], [], []
for i in click_count.index.levels[0]:
    banner_pos_idx.append(i)
    v1.append(click_count[i][0])
    v2.append(click_count[i][1])

fig,ax=plt.subplots()
ax.bar(range(len(banner_pos_idx)), v1, color='green')
ax.bar(range(len(banner_pos_idx)), v2, color='red')
ax.legend(['1','0'], title='click')
plt.xticks(range(len(banner_pos_idx)), banner_pos_idx)
ax.set(xlabel='banner_pos',title='Visualization of Banner Position and Click Events')
plt.show()
# Out:
# banner_pos  click
# 0           0        266217
#             1         49810
# 1           0         66955
#             1         16484
# 2           0           110
#             1            12
# 4           0            13
#             1             2
# 5           0           318
#             1            45
# 7           0            30
#             1             3
# Name: click, dtype: int64

# %% [markdown]
# > ``问题5（TODO)``： 生成完上面的图之后能感觉到这个特征还是蛮重要的，而且由于``banner_pos=2,4,5,7``的样本比较少，在图里不那么直观。所以我们就尝试打印一下一个表格。表格里的每一行针对于的是banner_pos具体的值，另外表格有两列，分别是false和true,  分别代表在某一个banner_pos的样本，有百分之多少的概率不被点击和被点击。 生成出来的表格如下图所示：
# <img src="sample_img2.png" alt="drawing" width="200"/>

# %%
# TODO: 生成如上面的表格
from operator import add, truediv
v_sum = list(map(add, v1, v2))
v1_per = list(map(truediv, v1, v_sum))
v2_per = list(map(truediv, v2, v_sum))

pos_click_per_df = pd.DataFrame({'banner_pos': banner_pos_idx, 'click 0': v1_per, 'click 1': v2_per})  
print(pos_click_per_df.to_string(index=False))
# Out:
#  banner_pos   click 0   click 1
#           0  0.842387  0.157613
#           1  0.802443  0.197557
#           2  0.901639  0.098361
#           4  0.866667  0.133333
#           5  0.876033  0.123967
#           7  0.909091  0.090909

# %% [markdown]
# #### ``site``相关特征 ####

# %%
site_features = ['site_id', 'site_domain', 'site_category']
data_df[site_features].describe()
# Out:
#          site_id site_domain site_category
# count     399999      399999        399999
# unique      1588        1464            21
# top     85f751fd    c4e18dd6      50e219e0
# freq      117380      122016        129039

# %%
app_features = ['app_id', 'app_domain', 'app_category']
data_df[app_features].describe()
# Out:
#           app_id app_domain app_category
# count     399999     399999       399999
# unique      1450        102           19
# top     ecad2386   7801e8d9     07d7df22
# freq      282619     298152       284444

# %% [markdown]
# > ``问题6（TODO）``:这里重点研究一下，``app_category``特征，看是否跟标签有比较强的关系。 为了理解这一点，对于每一种类型的``app_category``值，请画出``histogram``，展示每一种取值条件下样本被点击或者没有被点击的概率。效果图如下：
# <img src="sample_img3.png" alt="drawing" width="300"/>

# %%
# TODO: 画出如上这幅图。
click_count_2 = data_df.groupby(['app_category'])['click'].value_counts()
click_count_2 = click_count_2.to_frame()['click']

app_click_0, app_click_1, app_category_idx = [], [], []
for i in click_count_2.index.levels[0]:
    temp1, temp2 = 0, 0
    try:
        temp1 = click_count_2[i][0]
    except:
        pass
    try:
        temp2 = click_count_2[i][1]
    except:
        pass
    app_click_0.append(temp1)
    app_click_1.append(temp2)
    app_category_idx.append(i)

app_click_ratio_0 = list(map(add, app_click_0, app_click_1))
app_click_ratio_0 = list(map(truediv, app_click_0, app_click_ratio_0))
app_click_100 = [1]*len(app_click_ratio_0)

fig,ax=plt.subplots()
ax.bar(range(len(app_click_100)), app_click_100, color='green')
ax.bar(range(len(app_click_ratio_0)), app_click_ratio_0, color='red')
ax.legend(['1','0'], title='click', loc='lower left')
plt.xticks(range(len(app_category_idx)), app_category_idx, rotation=90)
ax.set(xlabel='app_category',title='CTR for app_category feature')
plt.show()

# %% [markdown]
# ####  ``device``相关的特征 ####
# 查看跟device相关的特征信息

# %%
device_features = ['device_id', 'device_ip', 'device_model', 'device_type', 'device_conn_type']
data_df[device_features].astype('object').describe()
# Out:
#        device_id device_ip device_model  device_type  device_conn_type
# count     399999    399999       399999       399999            399999
# unique     33226    141109         3757            4                 4
# top     a99f214a  6b9769f2     8a4875bd            1                 0
# freq      337979      2747        26552       377567            358831

# %% [markdown]
# > ``问题7(TODO)``: 对于不同的``device_conn_type``, 画一个histogram，并表示在不同type的情况下被点击和没有被点击的概率。效果图跟上面的问题（问题6）类似。

# %%
# TODO： 画出device_conn_type和CTR相关的histogram, 参考问题6的效果图。
click_count_2 = data_df.groupby(['device_conn_type'])['click'].value_counts()
click_count_2 = click_count_2.to_frame()['click']

app_click_0, app_click_1, app_category_idx = [], [], []
for i in click_count_2.index.levels[0]:
    temp1, temp2 = 0, 0
    try:
        temp1 = click_count_2[i][0]
    except:
        pass
    try:
        temp2 = click_count_2[i][1]
    except:
        pass
    app_click_0.append(temp1)
    app_click_1.append(temp2)
    app_category_idx.append(i)

app_click_ratio_0 = list(map(add, app_click_0, app_click_1))
app_click_ratio_0 = list(map(truediv, app_click_0, app_click_ratio_0))
app_click_100 = [1]*len(app_click_ratio_0)

fig,ax=plt.subplots()
ax.bar(range(len(app_click_100)), app_click_100, color='green')
ax.bar(range(len(app_click_ratio_0)), app_click_ratio_0, color='red')
ax.legend(['1','0'], title='click', loc='lower left')
plt.xticks(range(len(app_category_idx)), app_category_idx)
ax.set(xlabel='device_conn_type',title='CTR for device_conn_type feature')
plt.show()

# %% [markdown]
# #### ``C1, C14-C21`` 特征####
# 这些特征没有具体被标记到底是什么意思，有可能是涉及到公司的隐私。 当然，理解一个特征的含义其实挺重要的，但对于这个问题没办法，毕竟他们没有提供描述。但无论如何，也可以通过可视化分析去理解这些特征是否影响点击率。

# %%
c_features = ['C1', 'C14', 'C15', 'C16', 'C17', 'C18', 'C19', 'C20', 'C21']
data_df[c_features].astype('object').describe()
# Out:
#             C1     C14     C15     C16     C17     C18     C19     C20     C21
# count   399999  399999  399999  399999  399999  399999  399999  399999  399999
# unique       6     520       6       7     149       4      40     152      33
# top       1005   21647     320      50    1722       0      35      -1      79
# freq    376760   40254  380863  382421  125595  218396  192931  233501  125595

# %% [markdown]
# > ``问题8（TODO）``： 请画出C1和点击率之间的关系。请参考问题6的样例图。

# %%
# TODO: 画如上所要求的图
click_count_2 = data_df.groupby(['C1'])['click'].value_counts()
click_count_2 = click_count_2.to_frame()['click']

app_click_0, app_click_1, app_category_idx = [], [], []
for i in click_count_2.index.levels[0]:
    temp1, temp2 = 0, 0
    try:
        temp1 = click_count_2[i][0]
    except:
        pass
    try:
        temp2 = click_count_2[i][1]
    except:
        pass
    app_click_0.append(temp1)
    app_click_1.append(temp2)
    app_category_idx.append(i)

app_click_ratio_0 = list(map(add, app_click_0, app_click_1))
app_click_ratio_0 = list(map(truediv, app_click_0, app_click_ratio_0))
app_click_100 = [1]*len(app_click_ratio_0)

fig,ax=plt.subplots()
ax.bar(range(len(app_click_100)), app_click_100, color='green')
ax.bar(range(len(app_click_ratio_0)), app_click_ratio_0, color='red')
ax.legend(['1','0'], title='click', loc='lower left')
plt.xticks(range(len(app_category_idx)), app_category_idx)
ax.set(xlabel='C1',title='CTR for C1 feature')
plt.show()

# %% [markdown]
# ### 2. 特征的构造
# 特征构造对于一个机器学习建模非常重要。它的意思就是基于原有给定的特征基础上构造一些新的特征。构造特征的方法有很多： 1. 在原有的特征基础上做一些转换从而提取特征 2. 不同特征之间利用常规的运算来构造更复杂的特征（比如有特征f1, f2, 则可以通过f1 * f2操作生成新的特征)。
# 对于特征的构造在之后的项目中会有更详细的介绍，在这里，我们就简单的体验一下。
#
# 首先，我们来看一下数据集里的``hour``字段.

# %%
data_df['hour']
# Out:
# 0        2014-10-21 00:00:00
# 1        2014-10-21 00:00:00
# 2        2014-10-21 00:00:00
# 3        2014-10-21 00:00:00
# 4        2014-10-21 00:00:00
#                  ...
# 399994   2014-10-21 02:00:00
# 399995   2014-10-21 02:00:00
# 399996   2014-10-21 02:00:00
# 399997   2014-10-21 02:00:00
# 399998   2014-10-21 02:00:00
# Name: hour, Length: 399999, dtype: datetime64[ns]

# %% [markdown]
# 由于我们的数据只是做了部分采样，所以对于所有的样本日期是一致的。唯一不一样的是具体的时间。时间从10-21 00点到 10-21 02点，总共3个不同的时间段来记录。
#
# > ``问题9（TODO）``: 把``hour``这个字段转换成离散型变量，分别是0，1，2。 也就是2014-10-21 00点对应到0， 2014-10-21 01点对应到1， 2014-10-21 02点对应到2. 并把原来的``hour``字段替换一下。

# %%
# TODO:  实现问题9
data_df['hour'] = data_df['hour'].dt.hour
data_df.head()
# Out:
#    click  hour    C1  banner_pos   site_id site_domain site_category  \
# 0      0     0  1005           0  1fbe01fe    f3845767      28905ebd
# 1      0     0  1005           0  1fbe01fe    f3845767      28905ebd
# 2      0     0  1005           0  1fbe01fe    f3845767      28905ebd
# 3      0     0  1005           0  1fbe01fe    f3845767      28905ebd
# 4      0     0  1005           1  fe8cc448    9166c161      0569f928
#
#      app_id app_domain app_category  ... device_type device_conn_type    C14  \
# 0  ecad2386   7801e8d9     07d7df22  ...           1                2  15706
# 1  ecad2386   7801e8d9     07d7df22  ...           1                0  15704
# 2  ecad2386   7801e8d9     07d7df22  ...           1                0  15704
# 3  ecad2386   7801e8d9     07d7df22  ...           1                0  15706
# 4  ecad2386   7801e8d9     07d7df22  ...           1                0  18993
#
#    C15  C16   C17  C18  C19     C20  C21
# 0  320   50  1722    0   35      -1   79
# 1  320   50  1722    0   35  100084   79
# 2  320   50  1722    0   35  100084   79
# 3  320   50  1722    0   35  100084   79
# 4  320   50  2161    0   35      -1  157
#
# [5 rows x 23 columns]

# %% [markdown]
# ### 3. 特征转化
# 在上述数据中，存在着大量的类别型特征(categorical feature), 这部分的特征我们需要转换成独热编码的形式（one-hot encoding)，如果对这部分不熟悉，请参考之前的视频课程。 比如”男”，“女”这个特征分别转换成(0, 1), (1, 0)这种形式。

# %%
# 由于这两个特征的稀疏性，从特征库中去掉。 但如果计算资源允许，可以加入进来。 
data_df.drop('device_id', axis=1, inplace=True)
data_df.drop('device_ip', axis=1, inplace=True)
data_df.drop('device_model', axis=1, inplace=True)
data_df.drop('site_id', axis=1, inplace=True)
data_df.drop('site_domain', axis=1, inplace=True)
data_df.drop('app_id', axis=1, inplace=True)

# %%
# 输出数据的描述
data_df.astype('object').describe()
# Out:
#          click    hour      C1  banner_pos site_category app_domain  \
# count   399999  399999  399999      399999        399999     399999
# unique       2       3       6           6            21        102
# top          0       2    1005           0      50e219e0   7801e8d9
# freq    333643  143551  376760      316027        129039     298152
#
#        app_category  device_type  device_conn_type     C14     C15     C16  \
# count        399999       399999            399999  399999  399999  399999
# unique           19            4                 4     520       6       7
# top        07d7df22            1                 0   21647     320      50
# freq         284444       377567            358831   40254  380863  382421
#
#            C17     C18     C19     C20     C21
# count   399999  399999  399999  399999  399999
# unique     149       4      40     152      33
# top       1722       0      35      -1      79
# freq    125595  218396  192931  233501  125595

# %% [markdown]
# > ``问题10（TODO）`` 数据中的每一个特征，其实都可以看作是类别型特征（离散型）， 所以我们接下来要对所有的特征做独热编码的转换。这个时候总特征的维度就 变成每一个特征独热编码长度之和。 （也就是表格里的unique的之和）。务必要删除原始特征，因为已经把它们转换成了新的独热编码的形式。

# %%
# TODO: 实现对每一个特征的独热编码转换, 并删除原始特征
for item in data_df:
    if data_df[item].nunique()<=2:
        continue
    
    curr_data_df = data_df[item]
    curr_data_df = pd.get_dummies(curr_data_df)
    old_columns = curr_data_df.columns
    for i in old_columns:
        data_df[item+'_'+str(i)] = curr_data_df[i]
    
    data_df.drop(item, axis=1, inplace=True)

# %%
# 构造训练数据和测试数据
feature_names = np.array(data_df.columns[data_df.columns != 'click'].tolist())

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    data_df[feature_names].values, 
    data_df['click'].values,
    test_size=0.2,
    random_state=42
)

# %%
print (X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (319999, 1076) (80000, 1076) (319999,) (80000,)

# %% [markdown]
# ### 4. 特征选择
# 由于转换成了独热编码的形式，你会发现数据的维度一下子变多了，从几十维变成了上千维。接下来，我们来做个特征选择。我们可以回顾一下课程中提到的特征选择的方法， 也思考一下哪一种可能不太适合这个场景。 很显然生成所有的可能性方法和贪心方法是不太适合的，因为特征维度很高，计算量就变得特别大。在这里，我们使用基于L1+逻辑回归的方法。

# %% [markdown]
# > ``问题11（TODO）``： 使用基于L1的方法，请参考https://scikit-learn.org/stable/modules/feature_selection.html （SelectFromModel部分）。 我们使用的模型是逻辑回归 + L1的正则。 我们都知道L1正则会产生稀疏解，相当于帮我们选出特征。具体的方法是： 对于每一种可能的C值（代表正则的强弱)做交叉验证，从中选择效果最好的C值， 而且对于这个C值，我们有对应的选出来的特征。

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import f1_score
from sklearn.model_selection import KFold

import numpy as np
from tqdm import tqdm
# Tqdm 是一个快速，可扩展的Python进度条，可以在 Python 长循环中添加一个进度提示信息
import warnings
warnings.filterwarnings('always')

params_c = np.logspace(-4, 1, 11)

# TODO: 循环每一个C值，计算交叉验证后的F1-SCORE， 最终选择最好的C值c_best， 然后选出针对这个c_best对应的特征。 务必要使用L1正则。
#       对于实现，有很多方法，自行选择合理的方法就可以了。 关键是包括以下模块：1. 逻辑回归   2. 交叉验证  3. L1正则  4. SelectFromModel

fold = 5
kf = KFold(n_splits=fold, random_state=2001, shuffle=True)
f1_score_list = []
for c in tqdm(params_c):
    model = LogisticRegression(penalty='l1', solver='saga', C=c)
    f1_sum = 0
    for train_idx, valid_idx in tqdm(kf.split(X_train)):
        model.fit(X_train[train_idx], y_train[train_idx])
        y_pred = model.predict(X_train[valid_idx])
        f1_sum += f1_score(y_train[valid_idx], y_pred, average='weighted')
    f1_ave = f1_sum/fold
    f1_score_list.append(f1_ave)
# Out:
#   0%|                                                                                           | 0/11 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]D:\anaconda\envs\tensorflow\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#
# 1it [00:17, 17.42s/it]D:\anaconda\envs\tensorflow\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#
# 2it [00:34, 17.22s/it]D:\anaconda\envs\tensorflow\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#
# 3it [00:54, 18.21s/it]D:\anaconda\envs\tensorflow\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#
# 4it [01:14, 18.69s/it]D:\anaconda\envs\tensorflow\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#
# 5it [01:43, 20.73s/it]
#   9%|███████▍                                                                          | 1/11 [01:43<17:16, 103.67s/it]
# 0it [00:00, ?it/s]D:\anaconda\envs\tensorflow\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#
# 1it [00:49, 49.19s/it]D:\anaconda\envs\tensorflow\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#
# 2it [01:51, 53.21s/it]D:\anaconda\envs\tensorflow\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#
# 3it [02:59, 57.51s/it]D:\anaconda\envs\tensorflow\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#
# 4it [03:57, 57.86s/it]D:\anaconda\envs\tensorflow\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#
# 5it [04:57, 59.49s/it]
#  18%|██████████████▉                                                                   | 2/11 [06:41<24:16, 161.81s/it]
# 0it [00:00, ?it/s]D:\anaconda\envs\tensorflow\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#
# 1it [01:10, 70.04s/it]D:\anaconda\envs\tensorflow\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#
# 2it [02:23, 71.09s/it]D:\anaconda\envs\tensorflow\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#
# 3it [03:31, 70.00s/it]D:\anaconda\envs\tensorflow\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#
# 4it [04:45, 71.30s/it]D:\anaconda\envs\tensorflow\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#
# 5it [05:56, 71.25s/it]
#  27%|██████████████████████▎                                                           | 3/11 [12:37<29:21, 220.14s/it]
# 0it [00:00, ?it/s]D:\anaconda\envs\tensorflow\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#
# 1it [3:01:57, 10917.87s/it]

# %%
# it took me 2:23:09 to run the upper cell, i don't wanna run that again
# 求出c_best
c_best = params_c[f1_score_list.index(max(f1_score_list))]

# %%
# 通过c_best值，重新在整个X_train里做训练，并选出特征。
lr_clf = LogisticRegression(penalty='l1', C=c_best)
lr_clf.fit(X_train, y_train) # 在整个训练数据重新训练

select_model = SelectFromModel(lr_clf, prefit=True)
selected_features = select_model.get_support()  # 被选出来的特征

# 重新构造feature_names
feature_names = feature_names[selected_features]

# 重新构造训练数据和测试数据
X_train = X_train[:, selected_features]
X_test = X_test[:, selected_features]
# Out:
# //anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
print(len(feature_names))
print(feature_names)
# Out:
# 760
# ['hour_0' 'hour_1' 'hour_2' 'C1_1001' 'C1_1002' 'C1_1005' 'C1_1007'
#  'C1_1008' 'C1_1010' 'banner_pos_0' 'banner_pos_1' 'banner_pos_2'
#  'banner_pos_4' 'banner_pos_7' 'site_category_0569f928'
#  'site_category_110ab22d' 'site_category_28905ebd'
#  'site_category_335d28a8' 'site_category_3e814130'
#  'site_category_42a36e14' 'site_category_50e219e0'
#  'site_category_5378d028' 'site_category_70fb0e29'
#  'site_category_72722551' 'site_category_75fa27f6'
#  'site_category_76b2941d' 'site_category_8fd0aea4'
#  'site_category_9ccfa2ea' 'site_category_a818d37a'
#  'site_category_bcf865d9' 'site_category_c0dd3be3'
#  'site_category_dedf689d' 'site_category_e787de0e'
#  'site_category_f028772b' 'site_category_f66779e6' 'app_domain_0654b444'
#  'app_domain_0d79ee56' 'app_domain_0e8616ad' 'app_domain_15ec7f39'
#  'app_domain_18eb4e75' 'app_domain_1ea19ec4' 'app_domain_1ed56ded'
#  'app_domain_2347f47a' 'app_domain_24f896e0' 'app_domain_2b627705'
#  'app_domain_33da2e74' 'app_domain_3c992420' 'app_domain_43cf4f06'
#  'app_domain_44324ff4' 'app_domain_45a51db4' 'app_domain_47464e95'
#  'app_domain_48aec236' 'app_domain_4e007635' 'app_domain_56eabb45'
#  'app_domain_5ac0b939' 'app_domain_5b9c592b' 'app_domain_5c5a694b'
#  'app_domain_5c620f04' 'app_domain_6a0a3a9d' 'app_domain_6a90b0cb'
#  'app_domain_6cf43c3b' 'app_domain_6f7ca2ba' 'app_domain_73fc6786'
#  'app_domain_7801e8d9' 'app_domain_813f3323' 'app_domain_828da833'
#  'app_domain_82e27996' 'app_domain_88293ffa' 'app_domain_885c7f3f'
#  'app_domain_8bb7dba9' 'app_domain_8d87821d' 'app_domain_9acfe436'
#  'app_domain_ad63ec9b' 'app_domain_ae637522' 'app_domain_aefc06bd'
#  'app_domain_afdf1f54' 'app_domain_b12ff13e' 'app_domain_b2816726'
#  'app_domain_b408d42a' 'app_domain_b5f3b24a' 'app_domain_b8d325c3'
#  'app_domain_b9528b13' 'app_domain_c6824def' 'app_domain_d9b5648e'
#  'app_domain_db829551' 'app_domain_dcb74110' 'app_domain_df32afa9'
#  'app_domain_e787a6bc' 'app_domain_f2f777fb' 'app_domain_f3ad7798'
#  'app_domain_fd5f0ee2' 'app_category_07d7df22' 'app_category_09481d60'
#  'app_category_0f2161f8' 'app_category_4681bb9d' 'app_category_4ce2e9fc'
#  'app_category_75d80bbe' 'app_category_879c24eb' 'app_category_8ded1f7a'
#  'app_category_8df2e842' 'app_category_a3c42688' 'app_category_a7fd01ec'
#  'app_category_a86a3e89' 'app_category_cef3e649' 'app_category_d1327cf5'
#  'app_category_dc97ec06' 'app_category_f95efa07' 'app_category_fc6fa53d'
#  'device_type_0' 'device_type_1' 'device_type_5' 'device_conn_type_0'
#  'device_conn_type_2' 'device_conn_type_3' 'device_conn_type_5' 'C14_375'
#  'C14_380' 'C14_381' 'C14_452' 'C14_454' 'C14_456' 'C14_463' 'C14_1037'
#  'C14_1038' 'C14_1266' 'C14_1267' 'C14_1268' 'C14_1269' 'C14_1270'
#  'C14_1272' 'C14_1275' 'C14_1276' 'C14_4407' 'C14_4687' 'C14_5296'
#  'C14_6360' 'C14_6361' 'C14_6362' 'C14_6364' 'C14_6365' 'C14_6392'
#  'C14_6398' 'C14_6399' 'C14_6557' 'C14_6559' 'C14_6560' 'C14_6990'
#  'C14_6991' 'C14_6992' 'C14_7024' 'C14_8994' 'C14_8995' 'C14_9436'
#  'C14_9798' 'C14_9805' 'C14_10289' 'C14_11993' 'C14_11994' 'C14_11996'
#  'C14_12000' 'C14_12004' 'C14_12007' 'C14_12008' 'C14_12012' 'C14_12016'
#  'C14_12021' 'C14_12026' 'C14_12028' 'C14_12034' 'C14_12043' 'C14_12212'
#  'C14_12469' 'C14_12470' 'C14_12471' 'C14_12472' 'C14_13643' 'C14_13644'
#  'C14_13777' 'C14_13779' 'C14_13780' 'C14_13781' 'C14_13782' 'C14_13783'
#  'C14_14198' 'C14_14983' 'C14_14985' 'C14_15005' 'C14_15010' 'C14_15016'
#  'C14_15017' 'C14_15390' 'C14_15540' 'C14_15541' 'C14_15542' 'C14_15543'
#  'C14_15544' 'C14_15545' 'C14_15547' 'C14_15549' 'C14_15551' 'C14_15698'
#  'C14_15699' 'C14_15700' 'C14_15701' 'C14_15702' 'C14_15703' 'C14_15704'
#  'C14_15705' 'C14_15706' 'C14_15707' 'C14_15708' 'C14_15908' 'C14_16070'
#  'C14_16152' 'C14_16153' 'C14_16204' 'C14_16208' 'C14_16403' 'C14_16406'
#  'C14_16407' 'C14_16408' 'C14_16685' 'C14_16687' 'C14_16688' 'C14_16841'
#  'C14_16858' 'C14_16989' 'C14_17016' 'C14_17017' 'C14_17037' 'C14_17212'
#  'C14_17239' 'C14_17262' 'C14_17263' 'C14_17264' 'C14_17566' 'C14_17573'
#  'C14_17583' 'C14_17614' 'C14_17653' 'C14_17654' 'C14_17661' 'C14_17753'
#  'C14_17755' 'C14_17863' 'C14_17875' 'C14_17877' 'C14_17893' 'C14_17894'
#  'C14_17914' 'C14_18091' 'C14_18092' 'C14_18093' 'C14_18095' 'C14_18311'
#  'C14_18314' 'C14_18316' 'C14_18854' 'C14_18856' 'C14_18859' 'C14_18925'
#  'C14_18936' 'C14_18947' 'C14_18949' 'C14_18952' 'C14_18953' 'C14_18954'
#  'C14_18987' 'C14_18993' 'C14_19016' 'C14_19276' 'C14_19278' 'C14_19279'
#  'C14_19284' 'C14_19370' 'C14_19418' 'C14_19454' 'C14_19493' 'C14_19592'
#  'C14_19593' 'C14_19594' 'C14_19634' 'C14_19635' 'C14_19637' 'C14_19665'
#  'C14_19666' 'C14_19733' 'C14_19740' 'C14_19742' 'C14_19771' 'C14_19772'
#  'C14_19776' 'C14_19865' 'C14_19878' 'C14_19881' 'C14_19950' 'C14_19951'
#  'C14_19982' 'C14_19983' 'C14_19984' 'C14_19985' 'C14_19986' 'C14_19998'
#  'C14_20004' 'C14_20006' 'C14_20007' 'C14_20008' 'C14_20009' 'C14_20010'
#  'C14_20011' 'C14_20012' 'C14_20013' 'C14_20015' 'C14_20019' 'C14_20077'
#  'C14_20093' 'C14_20128' 'C14_20129' 'C14_20130' 'C14_20133' 'C14_20135'
#  'C14_20145' 'C14_20147' 'C14_20148' 'C14_20149' 'C14_20151' 'C14_20152'
#  'C14_20153' 'C14_20214' 'C14_20215' 'C14_20262' 'C14_20271' 'C14_20272'
#  'C14_20273' 'C14_20277' 'C14_20288' 'C14_20289' 'C14_20345' 'C14_20346'
#  'C14_20352' 'C14_20353' 'C14_20355' 'C14_20359' 'C14_20360' 'C14_20361'
#  'C14_20362' 'C14_20363' 'C14_20364' 'C14_20365' 'C14_20366' 'C14_20382'
#  'C14_20390' 'C14_20474' 'C14_20476' 'C14_20477' 'C14_20508' 'C14_20510'
#  'C14_20543' 'C14_20560' 'C14_20596' 'C14_20626' 'C14_20628' 'C14_20632'
#  'C14_20633' 'C14_20634' 'C14_20635' 'C14_20743' 'C14_20744' 'C14_20750'
#  'C14_20966' 'C14_20970' 'C14_20980' 'C14_20984' 'C14_21135' 'C14_21139'
#  'C14_21154' 'C14_21155' 'C14_21156' 'C14_21157' 'C14_21159' 'C14_21161'
#  'C14_21197' 'C14_21200' 'C14_21201' 'C14_21202' 'C14_21233' 'C14_21234'
#  'C14_21273' 'C14_21274' 'C14_21276' 'C14_21277' 'C14_21278' 'C14_21300'
#  'C14_21310' 'C14_21388' 'C14_21399' 'C14_21401' 'C14_21408' 'C14_21409'
#  'C14_21410' 'C14_21411' 'C14_21412' 'C14_21413' 'C14_21475' 'C14_21476'
#  'C14_21477' 'C14_21478' 'C14_21479' 'C14_21480' 'C14_21482' 'C14_21484'
#  'C14_21485' 'C14_21486' 'C14_21555' 'C14_21557' 'C14_21558' 'C14_21559'
#  'C14_21560' 'C14_21561' 'C14_21562' 'C14_21563' 'C14_21564' 'C14_21565'
#  'C14_21566' 'C14_21567' 'C14_21568' 'C14_21571' 'C14_21589' 'C14_21590'
#  'C14_21591' 'C14_21593' 'C14_21594' 'C14_21595' 'C14_21609' 'C14_21611'
#  'C14_21647' 'C14_21660' 'C14_21661' 'C14_21665' 'C14_21674' 'C14_21675'
#  'C14_21676' 'C14_21678' 'C14_21679' 'C14_21680' 'C14_21682' 'C14_21683'
#  'C14_21684' 'C14_21685' 'C14_21687' 'C14_21688' 'C14_21689' 'C14_21691'
#  'C14_21694' 'C14_21695' 'C14_21696' 'C14_21697' 'C14_21699' 'C14_21700'
#  'C14_21701' 'C14_21702' 'C14_21703' 'C14_21704' 'C14_21705' 'C15_216'
#  'C15_300' 'C15_320' 'C15_728' 'C15_1024' 'C16_36' 'C16_50' 'C16_90'
#  'C16_250' 'C16_480' 'C16_768' 'C17_112' 'C17_196' 'C17_423' 'C17_479'
#  'C17_544' 'C17_547' 'C17_549' 'C17_550' 'C17_571' 'C17_572' 'C17_576'
#  'C17_613' 'C17_686' 'C17_768' 'C17_827' 'C17_901' 'C17_937' 'C17_1008'
#  'C17_1092' 'C17_1255' 'C17_1272' 'C17_1515' 'C17_1722' 'C17_1752'
#  'C17_1800' 'C17_1835' 'C17_1872' 'C17_1873' 'C17_1882' 'C17_1884'
#  'C17_1887' 'C17_1921' 'C17_1926' 'C17_1934' 'C17_1973' 'C17_1974'
#  'C17_1993' 'C17_1994' 'C17_2036' 'C17_2043' 'C17_2060' 'C17_2154'
#  'C17_2161' 'C17_2162' 'C17_2201' 'C17_2206' 'C17_2218' 'C17_2225'
#  'C17_2227' 'C17_2242' 'C17_2250' 'C17_2253' 'C17_2263' 'C17_2264'
#  'C17_2270' 'C17_2271' 'C17_2278' 'C17_2284' 'C17_2285' 'C17_2286'
#  'C17_2292' 'C17_2295' 'C17_2303' 'C17_2304' 'C17_2306' 'C17_2307'
#  'C17_2316' 'C17_2323' 'C17_2333' 'C17_2339' 'C17_2346' 'C17_2372'
#  'C17_2374' 'C17_2397' 'C17_2421' 'C17_2427' 'C17_2443' 'C17_2446'
#  'C17_2449' 'C17_2459' 'C17_2471' 'C17_2478' 'C17_2480' 'C17_2481'
#  'C17_2482' 'C17_2487' 'C17_2492' 'C17_2495' 'C17_2496' 'C17_2497' 'C18_0'
#  'C18_1' 'C18_2' 'C18_3' 'C19_33' 'C19_35' 'C19_39' 'C19_43' 'C19_161'
#  'C19_163' 'C19_167' 'C19_169' 'C19_171' 'C19_175' 'C19_291' 'C19_297'
#  'C19_299' 'C19_303' 'C19_431' 'C19_547' 'C19_559' 'C19_679' 'C19_683'
#  'C19_687' 'C19_813' 'C19_1063' 'C19_1071' 'C19_1315' 'C19_1319'
#  'C19_1451' 'C19_1711' 'C19_1835' 'C20_-1' 'C20_100000' 'C20_100001'
#  'C20_100002' 'C20_100003' 'C20_100004' 'C20_100005' 'C20_100010'
#  'C20_100012' 'C20_100013' 'C20_100019' 'C20_100021' 'C20_100022'
#  'C20_100024' 'C20_100025' 'C20_100026' 'C20_100028' 'C20_100029'
#  'C20_100031' 'C20_100033' 'C20_100034' 'C20_100037' 'C20_100039'
#  'C20_100040' 'C20_100041' 'C20_100043' 'C20_100046' 'C20_100048'
#  'C20_100049' 'C20_100050' 'C20_100052' 'C20_100053' 'C20_100054'
#  'C20_100055' 'C20_100056' 'C20_100057' 'C20_100058' 'C20_100060'
#  'C20_100061' 'C20_100062' 'C20_100063' 'C20_100064' 'C20_100065'
#  'C20_100068' 'C20_100071' 'C20_100072' 'C20_100073' 'C20_100074'
#  'C20_100075' 'C20_100076' 'C20_100077' 'C20_100079' 'C20_100081'
#  'C20_100083' 'C20_100084' 'C20_100086' 'C20_100087' 'C20_100088'
#  'C20_100090' 'C20_100091' 'C20_100093' 'C20_100095' 'C20_100096'
#  'C20_100097' 'C20_100099' 'C20_100101' 'C20_100103' 'C20_100105'
#  'C20_100106' 'C20_100107' 'C20_100108' 'C20_100111' 'C20_100112'
#  'C20_100117' 'C20_100119' 'C20_100121' 'C20_100122' 'C20_100123'
#  'C20_100124' 'C20_100126' 'C20_100128' 'C20_100130' 'C20_100131'
#  'C20_100133' 'C20_100137' 'C20_100138' 'C20_100139' 'C20_100141'
#  'C20_100144' 'C20_100148' 'C20_100149' 'C20_100151' 'C20_100152'
#  'C20_100153' 'C20_100155' 'C20_100156' 'C20_100160' 'C20_100161'
#  'C20_100162' 'C20_100163' 'C20_100165' 'C20_100166' 'C20_100168'
#  'C20_100170' 'C20_100171' 'C20_100172' 'C20_100173' 'C20_100176'
#  'C20_100177' 'C20_100182' 'C20_100183' 'C20_100185' 'C20_100186'
#  'C20_100188' 'C20_100189' 'C20_100190' 'C20_100191' 'C20_100192'
#  'C20_100193' 'C20_100194' 'C20_100195' 'C20_100199' 'C20_100200'
#  'C20_100202' 'C20_100205' 'C20_100206' 'C20_100210' 'C20_100212'
#  'C20_100213' 'C20_100215' 'C20_100217' 'C20_100224' 'C20_100225'
#  'C20_100228' 'C20_100229' 'C20_100233' 'C20_100241' 'C20_100248' 'C21_13'
#  'C21_15' 'C21_16' 'C21_23' 'C21_32' 'C21_33' 'C21_42' 'C21_43' 'C21_46'
#  'C21_48' 'C21_51' 'C21_52' 'C21_61' 'C21_68' 'C21_69' 'C21_70' 'C21_71'
#  'C21_79' 'C21_85' 'C21_93' 'C21_95' 'C21_101' 'C21_111' 'C21_116'
#  'C21_157']

# %% [markdown]
# ### 5. 模型训练与评估
# 选择完特征之后，我们来构建模型并做训练。这部分的内容跟第一个项目没什么太大区别，无非就是选择模型之后，通过交叉验证来学习最好的超参数。在这里我们使用两种类型的模型，分别是逻辑回归+L2正则，以及决策树。 第二种模型还没有讲解，但没关系，我们只是在这里调用一下而已，在之后的章节里会详细地涉及到。

# %% [markdown]
# ### 5.1 使用逻辑回归模型
# > ``问题12（TODO）``在我们选择特征的时候其实也用了逻辑回归，但要记住，选特征的时候用的是L1的正则。但是在真正来训练最终版本模型的时候我们通常都是使用L2正则。所以这里就按照这个逻辑来训练一个逻辑回归模型。需要注意的一点是：评价标准使用F1-SCORE, 包括在交叉验证阶段。

# %%
from sklearn.metrics import classification_report  #  这个用来打印最终的结果，包括F1-SCORE

params_c = np.logspace(-5,2,15) # 也可以自行定义一个范围

# TODO: 实现逻辑回归 + L2正则， 利用GrisSearchCV

model = GridSearchCV(LogisticRegression(penalty='l2', solver='saga'), {'C':params_c}, cv=5)
model.fit(X_train, y_train)

# 输出最好的参数 
print(model.best_params_)
# Out:
# //anaconda3/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# //anaconda3/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# //anaconda3/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# //anaconda3/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# //anaconda3/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# //anaconda3/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# //anaconda3/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# //anaconda3/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# //anaconda3/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# //anaconda3/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# //anaconda3/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# //anaconda3/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# //anaconda3/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# //anaconda3/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# //anaconda3/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# //anaconda3/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# //anaconda3/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# //anaconda3/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# //anaconda3/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# //anaconda3/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# //anaconda3/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# //anaconda3/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# //anaconda3/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# //anaconda3/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# //anaconda3/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# {'C': 0.01}

# %%
# TODO: 在测试数据上预测，并打印在测试集上的结果
predictions = model.predict(X_test)
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.98      0.91     66743
#            1       0.54      0.10      0.16     13257
#
#     accuracy                           0.84     80000
#    macro avg       0.69      0.54      0.54     80000
# weighted avg       0.79      0.84      0.79     80000

# %% [markdown]
# ### 5.2 使用决策树模型
# > ``问题13（TODO）：``在这里，我们使用决策树算法做分类。这部分内容还没有讲到，但没关系，在这里只是用来调用。在PART3里会涉及到决策树的细节。 决策树本身有很多超参数需要调节，所以调节决策树的复杂度要远高于逻辑回归模型。决策树的使用请参考: https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html

# %%
from sklearn.tree import DecisionTreeClassifier
# from sklearn.model_selection import cross_val_score

params_min_samples_split = np.linspace(5, 20, 4)
params_min_samples_leaf = np.linspace(2, 10, 5)
params_max_depth = np.linspace(4, 10, 4)

params_min_samples_split = params_min_samples_split.astype(int)
params_min_samples_leaf = params_min_samples_leaf.astype(int)
params_max_depth = params_max_depth.astype(int)

# TODO: 构造决策树，并做交叉验证。 除了上面三个参数，其他参数用默认的。 

para_dict = {}
para_dict['min_samples_split'] = params_min_samples_split
para_dict['min_samples_leaf'] = params_min_samples_leaf
para_dict['max_depth'] = params_max_depth

# model = DecisionTreeClassifier()
# cross_val_score(model, X_train, y_train, fit_params=para_dict, cv=10)
model = GridSearchCV(DecisionTreeClassifier(), para_dict, cv=3, verbose=10)
model.fit(X_train, y_train)

# 输出最好的参数 
print(model.best_params_)
# Out:
# Fitting 3 folds for each of 80 candidates, totalling 240 fits
# [CV] max_depth=4, min_samples_leaf=2, min_samples_split=5 ............
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  max_depth=4, min_samples_leaf=2, min_samples_split=5, score=0.837, total=  10.6s
# [CV] max_depth=4, min_samples_leaf=2, min_samples_split=5 ............
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   10.7s remaining:    0.0s
# [CV]  max_depth=4, min_samples_leaf=2, min_samples_split=5, score=0.837, total=  11.8s
# [CV] max_depth=4, min_samples_leaf=2, min_samples_split=5 ............
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:   22.5s remaining:    0.0s
# [CV]  max_depth=4, min_samples_leaf=2, min_samples_split=5, score=0.836, total=  10.6s
# [CV] max_depth=4, min_samples_leaf=2, min_samples_split=10 ...........
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:   33.1s remaining:    0.0s
# [CV]  max_depth=4, min_samples_leaf=2, min_samples_split=10, score=0.837, total=  10.7s
# [CV] max_depth=4, min_samples_leaf=2, min_samples_split=10 ...........
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:   43.8s remaining:    0.0s
# [CV]  max_depth=4, min_samples_leaf=2, min_samples_split=10, score=0.837, total=  11.5s
# [CV] max_depth=4, min_samples_leaf=2, min_samples_split=10 ...........
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:   55.3s remaining:    0.0s
# [CV]  max_depth=4, min_samples_leaf=2, min_samples_split=10, score=0.836, total=  10.7s
# [CV] max_depth=4, min_samples_leaf=2, min_samples_split=15 ...........
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:  1.1min remaining:    0.0s
# [CV]  max_depth=4, min_samples_leaf=2, min_samples_split=15, score=0.837, total=  11.0s
# [CV] max_depth=4, min_samples_leaf=2, min_samples_split=15 ...........
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:  1.3min remaining:    0.0s
# [CV]  max_depth=4, min_samples_leaf=2, min_samples_split=15, score=0.837, total=  11.8s
# [CV] max_depth=4, min_samples_leaf=2, min_samples_split=15 ...........
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:  1.5min remaining:    0.0s
# [CV]  max_depth=4, min_samples_leaf=2, min_samples_split=15, score=0.836, total=  10.5s
# [CV] max_depth=4, min_samples_leaf=2, min_samples_split=20 ...........
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:  1.7min remaining:    0.0s
# [CV]  max_depth=4, min_samples_leaf=2, min_samples_split=20, score=0.837, total=  10.5s
# [CV] max_depth=4, min_samples_leaf=2, min_samples_split=20 ...........
# [CV]  max_depth=4, min_samples_leaf=2, min_samples_split=20, score=0.837, total=  10.8s
# [CV] max_depth=4, min_samples_leaf=2, min_samples_split=20 ...........
# [CV]  max_depth=4, min_samples_leaf=2, min_samples_split=20, score=0.836, total=  10.1s
# [CV] max_depth=4, min_samples_leaf=4, min_samples_split=5 ............
# [CV]  max_depth=4, min_samples_leaf=4, min_samples_split=5, score=0.837, total=  10.5s
# [CV] max_depth=4, min_samples_leaf=4, min_samples_split=5 ............
# [CV]  max_depth=4, min_samples_leaf=4, min_samples_split=5, score=0.837, total=  11.0s
# [CV] max_depth=4, min_samples_leaf=4, min_samples_split=5 ............
# [CV]  max_depth=4, min_samples_leaf=4, min_samples_split=5, score=0.836, total=   9.6s
# [CV] max_depth=4, min_samples_leaf=4, min_samples_split=10 ...........
# [CV]  max_depth=4, min_samples_leaf=4, min_samples_split=10, score=0.837, total=  10.2s
# [CV] max_depth=4, min_samples_leaf=4, min_samples_split=10 ...........
# [CV]  max_depth=4, min_samples_leaf=4, min_samples_split=10, score=0.837, total=  10.5s
# [CV] max_depth=4, min_samples_leaf=4, min_samples_split=10 ...........
# [CV]  max_depth=4, min_samples_leaf=4, min_samples_split=10, score=0.836, total=   9.4s
# [CV] max_depth=4, min_samples_leaf=4, min_samples_split=15 ...........
# [CV]  max_depth=4, min_samples_leaf=4, min_samples_split=15, score=0.837, total=   8.8s
# [CV] max_depth=4, min_samples_leaf=4, min_samples_split=15 ...........
# [CV]  max_depth=4, min_samples_leaf=4, min_samples_split=15, score=0.837, total=  11.6s
# [CV] max_depth=4, min_samples_leaf=4, min_samples_split=15 ...........
# [CV]  max_depth=4, min_samples_leaf=4, min_samples_split=15, score=0.836, total=  10.4s
# [CV] max_depth=4, min_samples_leaf=4, min_samples_split=20 ...........
# [CV]  max_depth=4, min_samples_leaf=4, min_samples_split=20, score=0.837, total=   9.8s
# [CV] max_depth=4, min_samples_leaf=4, min_samples_split=20 ...........
# [CV]  max_depth=4, min_samples_leaf=4, min_samples_split=20, score=0.837, total=  14.2s
# [CV] max_depth=4, min_samples_leaf=4, min_samples_split=20 ...........
# [CV]  max_depth=4, min_samples_leaf=4, min_samples_split=20, score=0.836, total=  10.1s
# [CV] max_depth=4, min_samples_leaf=6, min_samples_split=5 ............
# [CV]  max_depth=4, min_samples_leaf=6, min_samples_split=5, score=0.837, total=   9.2s
# [CV] max_depth=4, min_samples_leaf=6, min_samples_split=5 ............
# [CV]  max_depth=4, min_samples_leaf=6, min_samples_split=5, score=0.837, total=  10.2s
# [CV] max_depth=4, min_samples_leaf=6, min_samples_split=5 ............
# [CV]  max_depth=4, min_samples_leaf=6, min_samples_split=5, score=0.836, total=   9.6s
# [CV] max_depth=4, min_samples_leaf=6, min_samples_split=10 ...........
# [CV]  max_depth=4, min_samples_leaf=6, min_samples_split=10, score=0.837, total=  10.2s
# [CV] max_depth=4, min_samples_leaf=6, min_samples_split=10 ...........
# [CV]  max_depth=4, min_samples_leaf=6, min_samples_split=10, score=0.837, total=  10.7s
# [CV] max_depth=4, min_samples_leaf=6, min_samples_split=10 ...........
# [CV]  max_depth=4, min_samples_leaf=6, min_samples_split=10, score=0.836, total=  10.2s
# [CV] max_depth=4, min_samples_leaf=6, min_samples_split=15 ...........
# [CV]  max_depth=4, min_samples_leaf=6, min_samples_split=15, score=0.837, total=  10.5s
# [CV] max_depth=4, min_samples_leaf=6, min_samples_split=15 ...........
# [CV]  max_depth=4, min_samples_leaf=6, min_samples_split=15, score=0.837, total=  11.4s
# [CV] max_depth=4, min_samples_leaf=6, min_samples_split=15 ...........
# [CV]  max_depth=4, min_samples_leaf=6, min_samples_split=15, score=0.836, total=  10.8s
# [CV] max_depth=4, min_samples_leaf=6, min_samples_split=20 ...........
# [CV]  max_depth=4, min_samples_leaf=6, min_samples_split=20, score=0.837, total=  10.1s
# [CV] max_depth=4, min_samples_leaf=6, min_samples_split=20 ...........
# [CV]  max_depth=4, min_samples_leaf=6, min_samples_split=20, score=0.837, total=  10.3s
# [CV] max_depth=4, min_samples_leaf=6, min_samples_split=20 ...........
# [CV]  max_depth=4, min_samples_leaf=6, min_samples_split=20, score=0.836, total=  10.1s
# [CV] max_depth=4, min_samples_leaf=8, min_samples_split=5 ............
# [CV]  max_depth=4, min_samples_leaf=8, min_samples_split=5, score=0.837, total=  10.8s
# [CV] max_depth=4, min_samples_leaf=8, min_samples_split=5 ............
# [CV]  max_depth=4, min_samples_leaf=8, min_samples_split=5, score=0.837, total=  12.2s
# [CV] max_depth=4, min_samples_leaf=8, min_samples_split=5 ............
# [CV]  max_depth=4, min_samples_leaf=8, min_samples_split=5, score=0.836, total=  10.7s
# [CV] max_depth=4, min_samples_leaf=8, min_samples_split=10 ...........
# [CV]  max_depth=4, min_samples_leaf=8, min_samples_split=10, score=0.837, total=  10.7s
# [CV] max_depth=4, min_samples_leaf=8, min_samples_split=10 ...........
# [CV]  max_depth=4, min_samples_leaf=8, min_samples_split=10, score=0.837, total=  12.7s
# [CV] max_depth=4, min_samples_leaf=8, min_samples_split=10 ...........
# [CV]  max_depth=4, min_samples_leaf=8, min_samples_split=10, score=0.836, total=  11.0s
# [CV] max_depth=4, min_samples_leaf=8, min_samples_split=15 ...........
# [CV]  max_depth=4, min_samples_leaf=8, min_samples_split=15, score=0.837, total=  10.0s
# [CV] max_depth=4, min_samples_leaf=8, min_samples_split=15 ...........
# [CV]  max_depth=4, min_samples_leaf=8, min_samples_split=15, score=0.837, total=  10.7s
# [CV] max_depth=4, min_samples_leaf=8, min_samples_split=15 ...........
# [CV]  max_depth=4, min_samples_leaf=8, min_samples_split=15, score=0.836, total=   9.8s
# [CV] max_depth=4, min_samples_leaf=8, min_samples_split=20 ...........
# [CV]  max_depth=4, min_samples_leaf=8, min_samples_split=20, score=0.837, total=   9.9s
# [CV] max_depth=4, min_samples_leaf=8, min_samples_split=20 ...........
# [CV]  max_depth=4, min_samples_leaf=8, min_samples_split=20, score=0.837, total=  11.2s
# [CV] max_depth=4, min_samples_leaf=8, min_samples_split=20 ...........
# [CV]  max_depth=4, min_samples_leaf=8, min_samples_split=20, score=0.836, total=  10.4s
# [CV] max_depth=4, min_samples_leaf=10, min_samples_split=5 ...........
# [CV]  max_depth=4, min_samples_leaf=10, min_samples_split=5, score=0.837, total=  10.5s
# [CV] max_depth=4, min_samples_leaf=10, min_samples_split=5 ...........
# [CV]  max_depth=4, min_samples_leaf=10, min_samples_split=5, score=0.837, total=  11.3s
# [CV] max_depth=4, min_samples_leaf=10, min_samples_split=5 ...........
# [CV]  max_depth=4, min_samples_leaf=10, min_samples_split=5, score=0.836, total=  10.7s
# [CV] max_depth=4, min_samples_leaf=10, min_samples_split=10 ..........
# [CV]  max_depth=4, min_samples_leaf=10, min_samples_split=10, score=0.837, total=  11.0s
# [CV] max_depth=4, min_samples_leaf=10, min_samples_split=10 ..........
# [CV]  max_depth=4, min_samples_leaf=10, min_samples_split=10, score=0.837, total=  10.9s
# [CV] max_depth=4, min_samples_leaf=10, min_samples_split=10 ..........
# [CV]  max_depth=4, min_samples_leaf=10, min_samples_split=10, score=0.836, total=  10.8s
# [CV] max_depth=4, min_samples_leaf=10, min_samples_split=15 ..........
# [CV]  max_depth=4, min_samples_leaf=10, min_samples_split=15, score=0.837, total=  10.8s
# [CV] max_depth=4, min_samples_leaf=10, min_samples_split=15 ..........
# [CV]  max_depth=4, min_samples_leaf=10, min_samples_split=15, score=0.837, total=  11.6s
# [CV] max_depth=4, min_samples_leaf=10, min_samples_split=15 ..........
# [CV]  max_depth=4, min_samples_leaf=10, min_samples_split=15, score=0.836, total=   9.7s
# [CV] max_depth=4, min_samples_leaf=10, min_samples_split=20 ..........
# [CV]  max_depth=4, min_samples_leaf=10, min_samples_split=20, score=0.837, total=  10.8s
# [CV] max_depth=4, min_samples_leaf=10, min_samples_split=20 ..........
# [CV]  max_depth=4, min_samples_leaf=10, min_samples_split=20, score=0.837, total=  11.7s
# [CV] max_depth=4, min_samples_leaf=10, min_samples_split=20 ..........
# [CV]  max_depth=4, min_samples_leaf=10, min_samples_split=20, score=0.836, total=  10.4s
# [CV] max_depth=6, min_samples_leaf=2, min_samples_split=5 ............
# [CV]  max_depth=6, min_samples_leaf=2, min_samples_split=5, score=0.838, total=  12.9s
# [CV] max_depth=6, min_samples_leaf=2, min_samples_split=5 ............
# [CV]  max_depth=6, min_samples_leaf=2, min_samples_split=5, score=0.837, total=  15.0s
# [CV] max_depth=6, min_samples_leaf=2, min_samples_split=5 ............
# [CV]  max_depth=6, min_samples_leaf=2, min_samples_split=5, score=0.836, total=  12.0s
# [CV] max_depth=6, min_samples_leaf=2, min_samples_split=10 ...........
# [CV]  max_depth=6, min_samples_leaf=2, min_samples_split=10, score=0.838, total=  13.4s
# [CV] max_depth=6, min_samples_leaf=2, min_samples_split=10 ...........
# [CV]  max_depth=6, min_samples_leaf=2, min_samples_split=10, score=0.837, total=  14.3s
# [CV] max_depth=6, min_samples_leaf=2, min_samples_split=10 ...........
# [CV]  max_depth=6, min_samples_leaf=2, min_samples_split=10, score=0.836, total=  12.2s
# [CV] max_depth=6, min_samples_leaf=2, min_samples_split=15 ...........
# [CV]  max_depth=6, min_samples_leaf=2, min_samples_split=15, score=0.838, total=  11.9s
# [CV] max_depth=6, min_samples_leaf=2, min_samples_split=15 ...........
# [CV]  max_depth=6, min_samples_leaf=2, min_samples_split=15, score=0.837, total=  14.0s
# [CV] max_depth=6, min_samples_leaf=2, min_samples_split=15 ...........
# [CV]  max_depth=6, min_samples_leaf=2, min_samples_split=15, score=0.836, total=  13.0s
# [CV] max_depth=6, min_samples_leaf=2, min_samples_split=20 ...........
# [CV]  max_depth=6, min_samples_leaf=2, min_samples_split=20, score=0.838, total=  12.9s
# [CV] max_depth=6, min_samples_leaf=2, min_samples_split=20 ...........
# [CV]  max_depth=6, min_samples_leaf=2, min_samples_split=20, score=0.837, total=  15.1s
# [CV] max_depth=6, min_samples_leaf=2, min_samples_split=20 ...........
# [CV]  max_depth=6, min_samples_leaf=2, min_samples_split=20, score=0.836, total=  13.1s
# [CV] max_depth=6, min_samples_leaf=4, min_samples_split=5 ............
# [CV]  max_depth=6, min_samples_leaf=4, min_samples_split=5, score=0.838, total=  11.8s
# [CV] max_depth=6, min_samples_leaf=4, min_samples_split=5 ............
# [CV]  max_depth=6, min_samples_leaf=4, min_samples_split=5, score=0.837, total=  14.3s
# [CV] max_depth=6, min_samples_leaf=4, min_samples_split=5 ............
# [CV]  max_depth=6, min_samples_leaf=4, min_samples_split=5, score=0.836, total=  12.4s
# [CV] max_depth=6, min_samples_leaf=4, min_samples_split=10 ...........
# [CV]  max_depth=6, min_samples_leaf=4, min_samples_split=10, score=0.838, total=  11.1s
# [CV] max_depth=6, min_samples_leaf=4, min_samples_split=10 ...........
# [CV]  max_depth=6, min_samples_leaf=4, min_samples_split=10, score=0.837, total=  14.1s
# [CV] max_depth=6, min_samples_leaf=4, min_samples_split=10 ...........
# [CV]  max_depth=6, min_samples_leaf=4, min_samples_split=10, score=0.836, total=  11.9s
# [CV] max_depth=6, min_samples_leaf=4, min_samples_split=15 ...........
# [CV]  max_depth=6, min_samples_leaf=4, min_samples_split=15, score=0.838, total=  11.5s
# [CV] max_depth=6, min_samples_leaf=4, min_samples_split=15 ...........
# [CV]  max_depth=6, min_samples_leaf=4, min_samples_split=15, score=0.837, total=  13.3s
# [CV] max_depth=6, min_samples_leaf=4, min_samples_split=15 ...........
# [CV]  max_depth=6, min_samples_leaf=4, min_samples_split=15, score=0.836, total=  11.5s
# [CV] max_depth=6, min_samples_leaf=4, min_samples_split=20 ...........
# [CV]  max_depth=6, min_samples_leaf=4, min_samples_split=20, score=0.838, total=  11.5s
# [CV] max_depth=6, min_samples_leaf=4, min_samples_split=20 ...........
# [CV]  max_depth=6, min_samples_leaf=4, min_samples_split=20, score=0.837, total=  13.4s
# [CV] max_depth=6, min_samples_leaf=4, min_samples_split=20 ...........
# [CV]  max_depth=6, min_samples_leaf=4, min_samples_split=20, score=0.836, total=  11.3s
# [CV] max_depth=6, min_samples_leaf=6, min_samples_split=5 ............
# [CV]  max_depth=6, min_samples_leaf=6, min_samples_split=5, score=0.838, total=  11.3s
# [CV] max_depth=6, min_samples_leaf=6, min_samples_split=5 ............
# [CV]  max_depth=6, min_samples_leaf=6, min_samples_split=5, score=0.837, total=  10.5s
# [CV] max_depth=6, min_samples_leaf=6, min_samples_split=5 ............
# [CV]  max_depth=6, min_samples_leaf=6, min_samples_split=5, score=0.836, total=  14.2s
# [CV] max_depth=6, min_samples_leaf=6, min_samples_split=10 ...........
# [CV]  max_depth=6, min_samples_leaf=6, min_samples_split=10, score=0.838, total=  13.1s
# [CV] max_depth=6, min_samples_leaf=6, min_samples_split=10 ...........
# [CV]  max_depth=6, min_samples_leaf=6, min_samples_split=10, score=0.837, total=  15.5s
# [CV] max_depth=6, min_samples_leaf=6, min_samples_split=10 ...........
# [CV]  max_depth=6, min_samples_leaf=6, min_samples_split=10, score=0.836, total=  13.1s
# [CV] max_depth=6, min_samples_leaf=6, min_samples_split=15 ...........
# [CV]  max_depth=6, min_samples_leaf=6, min_samples_split=15, score=0.838, total=  13.1s
# [CV] max_depth=6, min_samples_leaf=6, min_samples_split=15 ...........
# [CV]  max_depth=6, min_samples_leaf=6, min_samples_split=15, score=0.837, total=  15.3s
# [CV] max_depth=6, min_samples_leaf=6, min_samples_split=15 ...........
# [CV]  max_depth=6, min_samples_leaf=6, min_samples_split=15, score=0.836, total=  13.3s
# [CV] max_depth=6, min_samples_leaf=6, min_samples_split=20 ...........
# [CV]  max_depth=6, min_samples_leaf=6, min_samples_split=20, score=0.838, total=  13.6s
# [CV] max_depth=6, min_samples_leaf=6, min_samples_split=20 ...........
# [CV]  max_depth=6, min_samples_leaf=6, min_samples_split=20, score=0.837, total=  15.1s
# [CV] max_depth=6, min_samples_leaf=6, min_samples_split=20 ...........
# [CV]  max_depth=6, min_samples_leaf=6, min_samples_split=20, score=0.836, total=  12.9s
# [CV] max_depth=6, min_samples_leaf=8, min_samples_split=5 ............
# [CV]  max_depth=6, min_samples_leaf=8, min_samples_split=5, score=0.838, total=  13.1s
# [CV] max_depth=6, min_samples_leaf=8, min_samples_split=5 ............
# [CV]  max_depth=6, min_samples_leaf=8, min_samples_split=5, score=0.837, total=  15.3s
# [CV] max_depth=6, min_samples_leaf=8, min_samples_split=5 ............
# [CV]  max_depth=6, min_samples_leaf=8, min_samples_split=5, score=0.836, total=  12.5s
# [CV] max_depth=6, min_samples_leaf=8, min_samples_split=10 ...........
# [CV]  max_depth=6, min_samples_leaf=8, min_samples_split=10, score=0.838, total=  10.4s
# [CV] max_depth=6, min_samples_leaf=8, min_samples_split=10 ...........
# [CV]  max_depth=6, min_samples_leaf=8, min_samples_split=10, score=0.837, total=  15.1s
# [CV] max_depth=6, min_samples_leaf=8, min_samples_split=10 ...........
# [CV]  max_depth=6, min_samples_leaf=8, min_samples_split=10, score=0.836, total=  10.6s
# [CV] max_depth=6, min_samples_leaf=8, min_samples_split=15 ...........
# [CV]  max_depth=6, min_samples_leaf=8, min_samples_split=15, score=0.838, total=  12.4s
# [CV] max_depth=6, min_samples_leaf=8, min_samples_split=15 ...........
# [CV]  max_depth=6, min_samples_leaf=8, min_samples_split=15, score=0.837, total=  15.9s
# [CV] max_depth=6, min_samples_leaf=8, min_samples_split=15 ...........
# [CV]  max_depth=6, min_samples_leaf=8, min_samples_split=15, score=0.836, total=  13.2s
# [CV] max_depth=6, min_samples_leaf=8, min_samples_split=20 ...........
# [CV]  max_depth=6, min_samples_leaf=8, min_samples_split=20, score=0.838, total=  13.0s
# [CV] max_depth=6, min_samples_leaf=8, min_samples_split=20 ...........
# [CV]  max_depth=6, min_samples_leaf=8, min_samples_split=20, score=0.837, total=  14.2s
# [CV] max_depth=6, min_samples_leaf=8, min_samples_split=20 ...........
# [CV]  max_depth=6, min_samples_leaf=8, min_samples_split=20, score=0.836, total=  12.1s
# [CV] max_depth=6, min_samples_leaf=10, min_samples_split=5 ...........
# [CV]  max_depth=6, min_samples_leaf=10, min_samples_split=5, score=0.838, total=  11.7s
# [CV] max_depth=6, min_samples_leaf=10, min_samples_split=5 ...........
# [CV]  max_depth=6, min_samples_leaf=10, min_samples_split=5, score=0.837, total=  13.2s
# [CV] max_depth=6, min_samples_leaf=10, min_samples_split=5 ...........
# [CV]  max_depth=6, min_samples_leaf=10, min_samples_split=5, score=0.836, total=  12.5s
# [CV] max_depth=6, min_samples_leaf=10, min_samples_split=10 ..........
# [CV]  max_depth=6, min_samples_leaf=10, min_samples_split=10, score=0.838, total=  12.8s
# [CV] max_depth=6, min_samples_leaf=10, min_samples_split=10 ..........
# [CV]  max_depth=6, min_samples_leaf=10, min_samples_split=10, score=0.837, total=  14.5s
# [CV] max_depth=6, min_samples_leaf=10, min_samples_split=10 ..........
# [CV]  max_depth=6, min_samples_leaf=10, min_samples_split=10, score=0.836, total=  12.2s
# [CV] max_depth=6, min_samples_leaf=10, min_samples_split=15 ..........
# [CV]  max_depth=6, min_samples_leaf=10, min_samples_split=15, score=0.838, total=  11.1s
# [CV] max_depth=6, min_samples_leaf=10, min_samples_split=15 ..........
# [CV]  max_depth=6, min_samples_leaf=10, min_samples_split=15, score=0.837, total=  14.1s
# [CV] max_depth=6, min_samples_leaf=10, min_samples_split=15 ..........
# [CV]  max_depth=6, min_samples_leaf=10, min_samples_split=15, score=0.836, total=  12.0s
# [CV] max_depth=6, min_samples_leaf=10, min_samples_split=20 ..........
# [CV]  max_depth=6, min_samples_leaf=10, min_samples_split=20, score=0.838, total=  12.1s
# [CV] max_depth=6, min_samples_leaf=10, min_samples_split=20 ..........
# [CV]  max_depth=6, min_samples_leaf=10, min_samples_split=20, score=0.837, total=  14.2s
# [CV] max_depth=6, min_samples_leaf=10, min_samples_split=20 ..........
# [CV]  max_depth=6, min_samples_leaf=10, min_samples_split=20, score=0.836, total=  12.1s
# [CV] max_depth=8, min_samples_leaf=2, min_samples_split=5 ............
# [CV]  max_depth=8, min_samples_leaf=2, min_samples_split=5, score=0.838, total=  14.0s
# [CV] max_depth=8, min_samples_leaf=2, min_samples_split=5 ............
# [CV]  max_depth=8, min_samples_leaf=2, min_samples_split=5, score=0.837, total=  16.3s
# [CV] max_depth=8, min_samples_leaf=2, min_samples_split=5 ............
# [CV]  max_depth=8, min_samples_leaf=2, min_samples_split=5, score=0.836, total=  13.8s
# [CV] max_depth=8, min_samples_leaf=2, min_samples_split=10 ...........
# [CV]  max_depth=8, min_samples_leaf=2, min_samples_split=10, score=0.838, total=  14.2s
# [CV] max_depth=8, min_samples_leaf=2, min_samples_split=10 ...........
# [CV]  max_depth=8, min_samples_leaf=2, min_samples_split=10, score=0.837, total=  16.6s
# [CV] max_depth=8, min_samples_leaf=2, min_samples_split=10 ...........
# [CV]  max_depth=8, min_samples_leaf=2, min_samples_split=10, score=0.836, total=  14.1s
# [CV] max_depth=8, min_samples_leaf=2, min_samples_split=15 ...........
# [CV]  max_depth=8, min_samples_leaf=2, min_samples_split=15, score=0.838, total=  14.2s
# [CV] max_depth=8, min_samples_leaf=2, min_samples_split=15 ...........
# [CV]  max_depth=8, min_samples_leaf=2, min_samples_split=15, score=0.837, total=  16.8s
# [CV] max_depth=8, min_samples_leaf=2, min_samples_split=15 ...........
# [CV]  max_depth=8, min_samples_leaf=2, min_samples_split=15, score=0.836, total=  14.2s
# [CV] max_depth=8, min_samples_leaf=2, min_samples_split=20 ...........
# [CV]  max_depth=8, min_samples_leaf=2, min_samples_split=20, score=0.838, total=  12.2s
# [CV] max_depth=8, min_samples_leaf=2, min_samples_split=20 ...........
# [CV]  max_depth=8, min_samples_leaf=2, min_samples_split=20, score=0.837, total=  14.0s
# [CV] max_depth=8, min_samples_leaf=2, min_samples_split=20 ...........
# [CV]  max_depth=8, min_samples_leaf=2, min_samples_split=20, score=0.836, total=  11.4s
# [CV] max_depth=8, min_samples_leaf=4, min_samples_split=5 ............
# [CV]  max_depth=8, min_samples_leaf=4, min_samples_split=5, score=0.838, total=  10.8s
# [CV] max_depth=8, min_samples_leaf=4, min_samples_split=5 ............
# [CV]  max_depth=8, min_samples_leaf=4, min_samples_split=5, score=0.837, total=  13.9s
# [CV] max_depth=8, min_samples_leaf=4, min_samples_split=5 ............
# [CV]  max_depth=8, min_samples_leaf=4, min_samples_split=5, score=0.837, total=  15.8s
# [CV] max_depth=8, min_samples_leaf=4, min_samples_split=10 ...........
# [CV]  max_depth=8, min_samples_leaf=4, min_samples_split=10, score=0.838, total=  13.3s
# [CV] max_depth=8, min_samples_leaf=4, min_samples_split=10 ...........
# [CV]  max_depth=8, min_samples_leaf=4, min_samples_split=10, score=0.837, total=  14.2s
# [CV] max_depth=8, min_samples_leaf=4, min_samples_split=10 ...........
# [CV]  max_depth=8, min_samples_leaf=4, min_samples_split=10, score=0.837, total=  15.0s
# [CV] max_depth=8, min_samples_leaf=4, min_samples_split=15 ...........
# [CV]  max_depth=8, min_samples_leaf=4, min_samples_split=15, score=0.838, total=  12.7s
# [CV] max_depth=8, min_samples_leaf=4, min_samples_split=15 ...........
# [CV]  max_depth=8, min_samples_leaf=4, min_samples_split=15, score=0.837, total=  17.2s
# [CV] max_depth=8, min_samples_leaf=4, min_samples_split=15 ...........
# [CV]  max_depth=8, min_samples_leaf=4, min_samples_split=15, score=0.837, total=  14.8s
# [CV] max_depth=8, min_samples_leaf=4, min_samples_split=20 ...........
# [CV]  max_depth=8, min_samples_leaf=4, min_samples_split=20, score=0.838, total=  14.6s
# [CV] max_depth=8, min_samples_leaf=4, min_samples_split=20 ...........
# [CV]  max_depth=8, min_samples_leaf=4, min_samples_split=20, score=0.837, total=  17.2s
# [CV] max_depth=8, min_samples_leaf=4, min_samples_split=20 ...........
# [CV]  max_depth=8, min_samples_leaf=4, min_samples_split=20, score=0.837, total=  15.0s
# [CV] max_depth=8, min_samples_leaf=6, min_samples_split=5 ............
# [CV]  max_depth=8, min_samples_leaf=6, min_samples_split=5, score=0.838, total=  14.9s
# [CV] max_depth=8, min_samples_leaf=6, min_samples_split=5 ............
# [CV]  max_depth=8, min_samples_leaf=6, min_samples_split=5, score=0.837, total=  16.1s
# [CV] max_depth=8, min_samples_leaf=6, min_samples_split=5 ............
# [CV]  max_depth=8, min_samples_leaf=6, min_samples_split=5, score=0.837, total=  13.5s
# [CV] max_depth=8, min_samples_leaf=6, min_samples_split=10 ...........
# [CV]  max_depth=8, min_samples_leaf=6, min_samples_split=10, score=0.838, total=  15.1s
# [CV] max_depth=8, min_samples_leaf=6, min_samples_split=10 ...........
# [CV]  max_depth=8, min_samples_leaf=6, min_samples_split=10, score=0.837, total=  17.6s
# [CV] max_depth=8, min_samples_leaf=6, min_samples_split=10 ...........
# [CV]  max_depth=8, min_samples_leaf=6, min_samples_split=10, score=0.837, total=  13.7s
# [CV] max_depth=8, min_samples_leaf=6, min_samples_split=15 ...........
# [CV]  max_depth=8, min_samples_leaf=6, min_samples_split=15, score=0.838, total=  14.8s
# [CV] max_depth=8, min_samples_leaf=6, min_samples_split=15 ...........
# [CV]  max_depth=8, min_samples_leaf=6, min_samples_split=15, score=0.837, total=  15.1s
# [CV] max_depth=8, min_samples_leaf=6, min_samples_split=15 ...........
# [CV]  max_depth=8, min_samples_leaf=6, min_samples_split=15, score=0.837, total=  13.7s
# [CV] max_depth=8, min_samples_leaf=6, min_samples_split=20 ...........
# [CV]  max_depth=8, min_samples_leaf=6, min_samples_split=20, score=0.838, total=  14.0s
# [CV] max_depth=8, min_samples_leaf=6, min_samples_split=20 ...........
# [CV]  max_depth=8, min_samples_leaf=6, min_samples_split=20, score=0.837, total=  16.4s
# [CV] max_depth=8, min_samples_leaf=6, min_samples_split=20 ...........
# [CV]  max_depth=8, min_samples_leaf=6, min_samples_split=20, score=0.837, total=  13.5s
# [CV] max_depth=8, min_samples_leaf=8, min_samples_split=5 ............
# [CV]  max_depth=8, min_samples_leaf=8, min_samples_split=5, score=0.838, total=  14.6s
# [CV] max_depth=8, min_samples_leaf=8, min_samples_split=5 ............
# [CV]  max_depth=8, min_samples_leaf=8, min_samples_split=5, score=0.837, total=  17.6s
# [CV] max_depth=8, min_samples_leaf=8, min_samples_split=5 ............
# [CV]  max_depth=8, min_samples_leaf=8, min_samples_split=5, score=0.837, total=  15.2s
# [CV] max_depth=8, min_samples_leaf=8, min_samples_split=10 ...........
# [CV]  max_depth=8, min_samples_leaf=8, min_samples_split=10, score=0.838, total=  15.0s
# [CV] max_depth=8, min_samples_leaf=8, min_samples_split=10 ...........
# [CV]  max_depth=8, min_samples_leaf=8, min_samples_split=10, score=0.837, total=  17.6s
# [CV] max_depth=8, min_samples_leaf=8, min_samples_split=10 ...........
# [CV]  max_depth=8, min_samples_leaf=8, min_samples_split=10, score=0.837, total=  14.3s
# [CV] max_depth=8, min_samples_leaf=8, min_samples_split=15 ...........
# [CV]  max_depth=8, min_samples_leaf=8, min_samples_split=15, score=0.838, total=  12.7s
# [CV] max_depth=8, min_samples_leaf=8, min_samples_split=15 ...........
# [CV]  max_depth=8, min_samples_leaf=8, min_samples_split=15, score=0.837, total=  15.1s
# [CV] max_depth=8, min_samples_leaf=8, min_samples_split=15 ...........
# [CV]  max_depth=8, min_samples_leaf=8, min_samples_split=15, score=0.837, total=  15.0s
# [CV] max_depth=8, min_samples_leaf=8, min_samples_split=20 ...........
# [CV]  max_depth=8, min_samples_leaf=8, min_samples_split=20, score=0.838, total=  14.3s
# [CV] max_depth=8, min_samples_leaf=8, min_samples_split=20 ...........
# [CV]  max_depth=8, min_samples_leaf=8, min_samples_split=20, score=0.837, total=  17.6s
# [CV] max_depth=8, min_samples_leaf=8, min_samples_split=20 ...........
# [CV]  max_depth=8, min_samples_leaf=8, min_samples_split=20, score=0.837, total=  15.0s
# [CV] max_depth=8, min_samples_leaf=10, min_samples_split=5 ...........
# [CV]  max_depth=8, min_samples_leaf=10, min_samples_split=5, score=0.838, total=  13.7s
# [CV] max_depth=8, min_samples_leaf=10, min_samples_split=5 ...........
# [CV]  max_depth=8, min_samples_leaf=10, min_samples_split=5, score=0.837, total=  16.7s
# [CV] max_depth=8, min_samples_leaf=10, min_samples_split=5 ...........
# [CV]  max_depth=8, min_samples_leaf=10, min_samples_split=5, score=0.837, total=  13.9s
# [CV] max_depth=8, min_samples_leaf=10, min_samples_split=10 ..........
# [CV]  max_depth=8, min_samples_leaf=10, min_samples_split=10, score=0.838, total=  14.5s
# [CV] max_depth=8, min_samples_leaf=10, min_samples_split=10 ..........
# [CV]  max_depth=8, min_samples_leaf=10, min_samples_split=10, score=0.837, total=  17.0s
# [CV] max_depth=8, min_samples_leaf=10, min_samples_split=10 ..........
# [CV]  max_depth=8, min_samples_leaf=10, min_samples_split=10, score=0.837, total=  15.6s
# [CV] max_depth=8, min_samples_leaf=10, min_samples_split=15 ..........
# [CV]  max_depth=8, min_samples_leaf=10, min_samples_split=15, score=0.838, total=  13.8s
# [CV] max_depth=8, min_samples_leaf=10, min_samples_split=15 ..........
# [CV]  max_depth=8, min_samples_leaf=10, min_samples_split=15, score=0.837, total=  12.5s
# [CV] max_depth=8, min_samples_leaf=10, min_samples_split=15 ..........
# [CV]  max_depth=8, min_samples_leaf=10, min_samples_split=15, score=0.837, total=  11.5s
# [CV] max_depth=8, min_samples_leaf=10, min_samples_split=20 ..........
# [CV]  max_depth=8, min_samples_leaf=10, min_samples_split=20, score=0.838, total=  11.8s
# [CV] max_depth=8, min_samples_leaf=10, min_samples_split=20 ..........
# [CV]  max_depth=8, min_samples_leaf=10, min_samples_split=20, score=0.837, total=  17.1s
# [CV] max_depth=8, min_samples_leaf=10, min_samples_split=20 ..........
# [CV]  max_depth=8, min_samples_leaf=10, min_samples_split=20, score=0.837, total=  14.3s
# [CV] max_depth=10, min_samples_leaf=2, min_samples_split=5 ...........
# [CV]  max_depth=10, min_samples_leaf=2, min_samples_split=5, score=0.838, total=  16.3s
# [CV] max_depth=10, min_samples_leaf=2, min_samples_split=5 ...........
# [CV]  max_depth=10, min_samples_leaf=2, min_samples_split=5, score=0.837, total=  15.9s
# [CV] max_depth=10, min_samples_leaf=2, min_samples_split=5 ...........
# [CV]  max_depth=10, min_samples_leaf=2, min_samples_split=5, score=0.836, total=  12.8s
# [CV] max_depth=10, min_samples_leaf=2, min_samples_split=10 ..........
# [CV]  max_depth=10, min_samples_leaf=2, min_samples_split=10, score=0.838, total=  12.9s
# [CV] max_depth=10, min_samples_leaf=2, min_samples_split=10 ..........
# [CV]  max_depth=10, min_samples_leaf=2, min_samples_split=10, score=0.837, total=  15.1s
# [CV] max_depth=10, min_samples_leaf=2, min_samples_split=10 ..........
# [CV]  max_depth=10, min_samples_leaf=2, min_samples_split=10, score=0.836, total=  15.0s
# [CV] max_depth=10, min_samples_leaf=2, min_samples_split=15 ..........
# [CV]  max_depth=10, min_samples_leaf=2, min_samples_split=15, score=0.838, total=  14.9s
# [CV] max_depth=10, min_samples_leaf=2, min_samples_split=15 ..........
# [CV]  max_depth=10, min_samples_leaf=2, min_samples_split=15, score=0.837, total=  17.8s
# [CV] max_depth=10, min_samples_leaf=2, min_samples_split=15 ..........
# [CV]  max_depth=10, min_samples_leaf=2, min_samples_split=15, score=0.836, total=  16.4s
# [CV] max_depth=10, min_samples_leaf=2, min_samples_split=20 ..........
# [CV]  max_depth=10, min_samples_leaf=2, min_samples_split=20, score=0.838, total=  16.3s
# [CV] max_depth=10, min_samples_leaf=2, min_samples_split=20 ..........
# [CV]  max_depth=10, min_samples_leaf=2, min_samples_split=20, score=0.837, total=  18.1s
# [CV] max_depth=10, min_samples_leaf=2, min_samples_split=20 ..........
# [CV]  max_depth=10, min_samples_leaf=2, min_samples_split=20, score=0.836, total=  16.1s
# [CV] max_depth=10, min_samples_leaf=4, min_samples_split=5 ...........
# [CV]  max_depth=10, min_samples_leaf=4, min_samples_split=5, score=0.838, total=  14.6s
# [CV] max_depth=10, min_samples_leaf=4, min_samples_split=5 ...........
# [CV]  max_depth=10, min_samples_leaf=4, min_samples_split=5, score=0.837, total=  19.5s
# [CV] max_depth=10, min_samples_leaf=4, min_samples_split=5 ...........
# [CV]  max_depth=10, min_samples_leaf=4, min_samples_split=5, score=0.836, total=  16.1s
# [CV] max_depth=10, min_samples_leaf=4, min_samples_split=10 ..........
# [CV]  max_depth=10, min_samples_leaf=4, min_samples_split=10, score=0.838, total=  14.6s
# [CV] max_depth=10, min_samples_leaf=4, min_samples_split=10 ..........
# [CV]  max_depth=10, min_samples_leaf=4, min_samples_split=10, score=0.837, total=  19.0s
# [CV] max_depth=10, min_samples_leaf=4, min_samples_split=10 ..........
# [CV]  max_depth=10, min_samples_leaf=4, min_samples_split=10, score=0.836, total=  16.1s
# [CV] max_depth=10, min_samples_leaf=4, min_samples_split=15 ..........
# [CV]  max_depth=10, min_samples_leaf=4, min_samples_split=15, score=0.838, total=  14.5s
# [CV] max_depth=10, min_samples_leaf=4, min_samples_split=15 ..........
# [CV]  max_depth=10, min_samples_leaf=4, min_samples_split=15, score=0.837, total=  17.4s
# [CV] max_depth=10, min_samples_leaf=4, min_samples_split=15 ..........
# [CV]  max_depth=10, min_samples_leaf=4, min_samples_split=15, score=0.836, total=  16.3s
# [CV] max_depth=10, min_samples_leaf=4, min_samples_split=20 ..........
# [CV]  max_depth=10, min_samples_leaf=4, min_samples_split=20, score=0.838, total=  16.3s
# [CV] max_depth=10, min_samples_leaf=4, min_samples_split=20 ..........
# [CV]  max_depth=10, min_samples_leaf=4, min_samples_split=20, score=0.837, total=  18.8s
# [CV] max_depth=10, min_samples_leaf=4, min_samples_split=20 ..........
# [CV]  max_depth=10, min_samples_leaf=4, min_samples_split=20, score=0.836, total=  15.9s
# [CV] max_depth=10, min_samples_leaf=6, min_samples_split=5 ...........
# [CV]  max_depth=10, min_samples_leaf=6, min_samples_split=5, score=0.838, total=  15.0s
# [CV] max_depth=10, min_samples_leaf=6, min_samples_split=5 ...........
# [CV]  max_depth=10, min_samples_leaf=6, min_samples_split=5, score=0.837, total=  17.9s
# [CV] max_depth=10, min_samples_leaf=6, min_samples_split=5 ...........
# [CV]  max_depth=10, min_samples_leaf=6, min_samples_split=5, score=0.836, total=  15.5s
# [CV] max_depth=10, min_samples_leaf=6, min_samples_split=10 ..........
# [CV]  max_depth=10, min_samples_leaf=6, min_samples_split=10, score=0.838, total=  15.8s
# [CV] max_depth=10, min_samples_leaf=6, min_samples_split=10 ..........
# [CV]  max_depth=10, min_samples_leaf=6, min_samples_split=10, score=0.837, total=  18.6s
# [CV] max_depth=10, min_samples_leaf=6, min_samples_split=10 ..........
# [CV]  max_depth=10, min_samples_leaf=6, min_samples_split=10, score=0.836, total=  15.9s
# [CV] max_depth=10, min_samples_leaf=6, min_samples_split=15 ..........
# [CV]  max_depth=10, min_samples_leaf=6, min_samples_split=15, score=0.838, total=  15.9s
# [CV] max_depth=10, min_samples_leaf=6, min_samples_split=15 ..........
# [CV]  max_depth=10, min_samples_leaf=6, min_samples_split=15, score=0.837, total=  19.9s
# [CV] max_depth=10, min_samples_leaf=6, min_samples_split=15 ..........
# [CV]  max_depth=10, min_samples_leaf=6, min_samples_split=15, score=0.836, total=  14.6s
# [CV] max_depth=10, min_samples_leaf=6, min_samples_split=20 ..........
# [CV]  max_depth=10, min_samples_leaf=6, min_samples_split=20, score=0.838, total=  15.6s
# [CV] max_depth=10, min_samples_leaf=6, min_samples_split=20 ..........
# [CV]  max_depth=10, min_samples_leaf=6, min_samples_split=20, score=0.837, total=  17.7s
# [CV] max_depth=10, min_samples_leaf=6, min_samples_split=20 ..........
# [CV]  max_depth=10, min_samples_leaf=6, min_samples_split=20, score=0.836, total=  13.6s
# [CV] max_depth=10, min_samples_leaf=8, min_samples_split=5 ...........
# [CV]  max_depth=10, min_samples_leaf=8, min_samples_split=5, score=0.838, total=  13.3s
# [CV] max_depth=10, min_samples_leaf=8, min_samples_split=5 ...........
# [CV]  max_depth=10, min_samples_leaf=8, min_samples_split=5, score=0.837, total=  15.8s
# [CV] max_depth=10, min_samples_leaf=8, min_samples_split=5 ...........
# [CV]  max_depth=10, min_samples_leaf=8, min_samples_split=5, score=0.837, total=  14.8s
# [CV] max_depth=10, min_samples_leaf=8, min_samples_split=10 ..........
# [CV]  max_depth=10, min_samples_leaf=8, min_samples_split=10, score=0.838, total=  15.9s
# [CV] max_depth=10, min_samples_leaf=8, min_samples_split=10 ..........
# [CV]  max_depth=10, min_samples_leaf=8, min_samples_split=10, score=0.837, total=  17.2s
# [CV] max_depth=10, min_samples_leaf=8, min_samples_split=10 ..........
# [CV]  max_depth=10, min_samples_leaf=8, min_samples_split=10, score=0.837, total=  15.0s
# [CV] max_depth=10, min_samples_leaf=8, min_samples_split=15 ..........
# [CV]  max_depth=10, min_samples_leaf=8, min_samples_split=15, score=0.838, total=  13.3s
# [CV] max_depth=10, min_samples_leaf=8, min_samples_split=15 ..........
# [CV]  max_depth=10, min_samples_leaf=8, min_samples_split=15, score=0.837, total=  16.5s
# [CV] max_depth=10, min_samples_leaf=8, min_samples_split=15 ..........
# [CV]  max_depth=10, min_samples_leaf=8, min_samples_split=15, score=0.837, total=  15.0s
# [CV] max_depth=10, min_samples_leaf=8, min_samples_split=20 ..........
# [CV]  max_depth=10, min_samples_leaf=8, min_samples_split=20, score=0.838, total=  16.6s
# [CV] max_depth=10, min_samples_leaf=8, min_samples_split=20 ..........
# [CV]  max_depth=10, min_samples_leaf=8, min_samples_split=20, score=0.837, total=  18.6s
# [CV] max_depth=10, min_samples_leaf=8, min_samples_split=20 ..........
# [CV]  max_depth=10, min_samples_leaf=8, min_samples_split=20, score=0.837, total=  15.2s
# [CV] max_depth=10, min_samples_leaf=10, min_samples_split=5 ..........
# [CV]  max_depth=10, min_samples_leaf=10, min_samples_split=5, score=0.838, total=  14.9s
# [CV] max_depth=10, min_samples_leaf=10, min_samples_split=5 ..........
# [CV]  max_depth=10, min_samples_leaf=10, min_samples_split=5, score=0.837, total=  18.2s
# [CV] max_depth=10, min_samples_leaf=10, min_samples_split=5 ..........
# [CV]  max_depth=10, min_samples_leaf=10, min_samples_split=5, score=0.836, total=  17.1s
# [CV] max_depth=10, min_samples_leaf=10, min_samples_split=10 .........
# [CV]  max_depth=10, min_samples_leaf=10, min_samples_split=10, score=0.838, total=  15.8s
# [CV] max_depth=10, min_samples_leaf=10, min_samples_split=10 .........
# [CV]  max_depth=10, min_samples_leaf=10, min_samples_split=10, score=0.837, total=  16.0s
# [CV] max_depth=10, min_samples_leaf=10, min_samples_split=10 .........
# [CV]  max_depth=10, min_samples_leaf=10, min_samples_split=10, score=0.836, total=  16.1s
# [CV] max_depth=10, min_samples_leaf=10, min_samples_split=15 .........
# [CV]  max_depth=10, min_samples_leaf=10, min_samples_split=15, score=0.838, total=  16.6s
# [CV] max_depth=10, min_samples_leaf=10, min_samples_split=15 .........
# [CV]  max_depth=10, min_samples_leaf=10, min_samples_split=15, score=0.837, total=  16.4s
# [CV] max_depth=10, min_samples_leaf=10, min_samples_split=15 .........
# [CV]  max_depth=10, min_samples_leaf=10, min_samples_split=15, score=0.836, total=  15.9s
# [CV] max_depth=10, min_samples_leaf=10, min_samples_split=20 .........
# [CV]  max_depth=10, min_samples_leaf=10, min_samples_split=20, score=0.838, total=  15.4s
# [CV] max_depth=10, min_samples_leaf=10, min_samples_split=20 .........
# [CV]  max_depth=10, min_samples_leaf=10, min_samples_split=20, score=0.837, total=  18.8s
# [CV] max_depth=10, min_samples_leaf=10, min_samples_split=20 .........
# [CV]  max_depth=10, min_samples_leaf=10, min_samples_split=20, score=0.836, total=  16.5s
# [Parallel(n_jobs=1)]: Done 240 out of 240 | elapsed: 54.5min finished
# {'max_depth': 8, 'min_samples_leaf': 8, 'min_samples_split': 20}

# %%
# TODO: 在测试数据上预测，并打印在测试集上的结果

predictions = model.predict(X_test)
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.98      0.91     66743
#            1       0.53      0.14      0.22     13257
#
#     accuracy                           0.84     80000
#    macro avg       0.69      0.56      0.56     80000
# weighted avg       0.80      0.84      0.79     80000

# %% [markdown]
# ### 5.3 利用启发式算法来调节参数（选做部分, 不计为分数）
# 在课程中，我们讲过启发式算法的大致思路。 在这里，我们使用贝叶斯优化方法去选择超参数，具体的使用方法请参考： https://github.com/fmfn/BayesianOptimization  也需要提前安装好这个库，请按照此链接中的方法来安装。
#
# 同时，我们在使用决策树的过程中也发现参数数量多，花费的时间也很长。这种现象在参数越多的时候越明显。所以，可以适当采用启发式算法比如贝叶斯优化。贝叶斯优化整体的思路是构建在贝叶斯模型之上的，内核包括高斯过程。具体细节可以参考Adam Ryans（princeton)教授的相关文章。
#
# 请认真读一下上述github的内容，应该可以大致理解它的主要作用。然后按照里面写的方法来实现决策树上的参数优化。

# %%
from bayes_opt import BayesianOptimization

params_min_samples_split = np.linspace(5, 20, 4)
# array([ 5., 10., 15., 20.])
params_min_samples_leaf = np.linspace(2, 10, 5)
# array([ 2.,  4.,  6.,  8., 10.])
params_max_depth = np.linspace(4, 10, 4)
# array([ 4.,  6.,  8., 10.])

# TODO: 使用贝叶斯优化去选择超参数

def decision_tree_predictor(min_samples_split, min_samples_leaf, max_depth):
    # discrete mapping
    min_samples_split = int(min_samples_split)*5
    min_samples_leaf = int(min_samples_leaf)*2
    max_depth = int(max_depth)*2+2
        
    model = DecisionTreeClassifier(min_samples_split=int(min_samples_split), min_samples_leaf=int(min_samples_leaf), max_depth=int(max_depth))
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    f1_ =  f1_score(y_test, y_pred, average='weighted')
    return f1_
    
    
para_dict = {}
para_dict['min_samples_split'] = (1, len(params_min_samples_split)+.99)
para_dict['min_samples_leaf'] = (1, len(params_min_samples_leaf)+.99)
para_dict['max_depth'] = (1, len(params_max_depth)+.99)
# plus .99 to approximate to equal space 

new_optimizer = BayesianOptimization(
    f=decision_tree_predictor,
    pbounds=para_dict,
    verbose=2,
    random_state=7,
)

new_optimizer.maximize(
    init_points=20,
    n_iter=30,
)
# Out:
# |   iter    |  target   | max_depth | min_sa... | min_sa... |
# -------------------------------------------------------------
# |  1        |  0.7867   |  1.304    |  4.892    |  2.749    |
# |  2        |  0.7873   |  3.887    |  5.88     |  3.149    |
# |  3        |  0.7891   |  2.999    |  1.36     |  2.071    |
# |  4        |  0.787    |  2.995    |  4.389    |  4.207    |
# |  5        |  0.7891   |  2.52     |  1.329    |  2.15     |
# |  6        |  0.7869   |  4.629    |  2.065    |  2.804    |
# |  7        |  0.7865   |  4.716    |  1.124    |  3.396    |
# |  8        |  0.7869   |  4.791    |  2.149    |  3.188    |
# |  9        |  0.7865   |  4.627    |  1.665    |  3.088    |
# |  10       |  0.7872   |  3.994    |  4.338    |  2.866    |
# |  11       |  0.7867   |  1.817    |  3.449    |  2.486    |
# |  12       |  0.7891   |  2.905    |  2.826    |  4.343    |
# |  13       |  0.7869   |  4.067    |  2.567    |  3.285    |
# |  14       |  0.787    |  2.101    |  3.26     |  2.408    |
# |  15       |  0.7889   |  3.623    |  2.848    |  2.832    |
# |  16       |  0.7873   |  3.87     |  3.061    |  4.617    |
# |  17       |  0.7867   |  1.72     |  4.698    |  2.685    |
# |  18       |  0.787    |  2.702    |  4.166    |  3.086    |
# |  19       |  0.7891   |  2.655    |  1.007    |  1.368    |
# |  20       |  0.7873   |  3.83     |  3.616    |  3.778    |
# |  21       |  0.7867   |  1.046    |  1.09     |  1.058    |
# |  22       |  0.7867   |  1.061    |  1.135    |  1.136    |
# |  23       |  0.7866   |  4.946    |  1.028    |  4.963    |
# |  24       |  0.7867   |  1.184    |  1.003    |  1.305    |
# |  25       |  0.7867   |  1.131    |  5.748    |  1.33     |
# |  26       |  0.7871   |  4.956    |  5.987    |  3.835    |
# |  27       |  0.7871   |  4.983    |  5.77     |  1.459    |
# |  28       |  0.7866   |  4.68     |  1.279    |  4.968    |
# |  29       |  0.7867   |  1.144    |  1.19     |  4.55     |
# |  30       |  0.7867   |  1.156    |  5.916    |  1.091    |
# |  31       |  0.7867   |  1.722    |  1.169    |  1.047    |
# |  32       |  0.7867   |  1.134    |  5.598    |  1.15     |
# |  33       |  0.7867   |  1.06     |  1.137    |  4.707    |
# |  34       |  0.7865   |  4.511    |  1.186    |  1.695    |
# |  35       |  0.7864   |  4.969    |  1.366    |  1.037    |
# |  36       |  0.7871   |  4.928    |  5.966    |  4.695    |
# |  37       |  0.7867   |  1.156    |  2.134    |  4.96     |
# |  38       |  0.7871   |  4.981    |  5.494    |  4.969    |
# |  39       |  0.7871   |  4.438    |  5.878    |  1.97     |
# |  40       |  0.7867   |  1.59     |  1.568    |  4.703    |
# |  41       |  0.7865   |  4.72     |  1.068    |  2.63     |
# |  42       |  0.787    |  2.556    |  5.087    |  1.037    |
# |  43       |  0.7866   |  4.47     |  1.474    |  4.052    |
# |  44       |  0.7867   |  1.083    |  5.828    |  1.46     |
# |  45       |  0.7867   |  1.852    |  1.326    |  4.758    |
# |  46       |  0.7891   |  2.344    |  1.355    |  3.92     |
# |  47       |  0.7867   |  1.332    |  5.735    |  4.752    |
# |  48       |  0.7871   |  4.336    |  5.851    |  4.304    |
# |  49       |  0.7864   |  4.002    |  1.438    |  1.515    |
# |  50       |  0.7865   |  4.011    |  1.16     |  3.244    |
# =============================================================

# %%
print(len(new_optimizer.space))
print(new_optimizer.max)

for i, res in enumerate(new_optimizer.res):
    print("Iteration {}: \n\t{}".format(i, res))
# Out:
# 50
# {'target': 0.789073105270768, 'params': {'max_depth': 2.9994706500031523, 'min_samples_leaf': 1.3595351554652102, 'min_samples_split': 2.071071530606466}}
# Iteration 0:
# 	{'target': 0.7866884574292446, 'params': {'max_depth': 1.3044700746020892, 'min_samples_leaf': 4.891794773278172, 'min_samples_split': 2.749252833449165}}
# Iteration 1:
# 	{'target': 0.7873170669832878, 'params': {'max_depth': 3.886626059545456, 'min_samples_leaf': 5.880167664863047, 'min_samples_split': 3.1485985229376303}}
# Iteration 2:
# 	{'target': 0.789073105270768, 'params': {'max_depth': 2.9994706500031523, 'min_samples_leaf': 1.3595351554652102, 'min_samples_split': 2.071071530606466}}
# Iteration 3:
# 	{'target': 0.7869964893176169, 'params': {'max_depth': 2.9945311782939843, 'min_samples_leaf': 4.389357680643493, 'min_samples_split': 4.206918754056458}}
# Iteration 4:
# 	{'target': 0.789073105270768, 'params': {'max_depth': 2.5199551212626683, 'min_samples_leaf': 1.3290223710604665, 'min_samples_split': 2.149700941238894}}
# Iteration 5:
# 	{'target': 0.7869339060209002, 'params': {'max_depth': 4.629278175601259, 'min_samples_leaf': 2.064792914363778, 'min_samples_split': 2.803974607652556}}
# Iteration 6:
# 	{'target': 0.7864889225139261, 'params': {'max_depth': 4.715512018559197, 'min_samples_leaf': 1.1242471454762366, 'min_samples_split': 3.396190180681849}}
# Iteration 7:
# 	{'target': 0.7869255967318644, 'params': {'max_depth': 4.791016706650446, 'min_samples_leaf': 2.1492113663146144, 'min_samples_split': 3.1884747777517615}}
# Iteration 8:
# 	{'target': 0.7864889225139261, 'params': {'max_depth': 4.627422215798058, 'min_samples_leaf': 1.6645155343386584, 'min_samples_split': 3.0884161968883257}}
# Iteration 9:
# 	{'target': 0.7872435860339527, 'params': {'max_depth': 3.994135337817119, 'min_samples_leaf': 4.33837607201073, 'min_samples_split': 2.8663339103824734}}
# Iteration 10:
# 	{'target': 0.7866884574292446, 'params': {'max_depth': 1.8173478702882024, 'min_samples_leaf': 3.4489217865644415, 'min_samples_split': 2.4858149106463854}}
# Iteration 11:
# 	{'target': 0.789073105270768, 'params': {'max_depth': 2.904830607857838, 'min_samples_leaf': 2.825793025045159, 'min_samples_split': 4.34329279729395}}
# Iteration 12:
# 	{'target': 0.7869255967318644, 'params': {'max_depth': 4.066903551012842, 'min_samples_leaf': 2.5668334392911842, 'min_samples_split': 3.2847750772493765}}
# Iteration 13:
# 	{'target': 0.7869967675170905, 'params': {'max_depth': 2.1014357028394732, 'min_samples_leaf': 3.259686233406538, 'min_samples_split': 2.408383680118135}}
# Iteration 14:
# 	{'target': 0.7888943197619555, 'params': {'max_depth': 3.6230238564912356, 'min_samples_leaf': 2.848051904110296, 'min_samples_split': 2.8317809817868116}}
# Iteration 15:
# 	{'target': 0.7873173417513539, 'params': {'max_depth': 3.870103248811076, 'min_samples_leaf': 3.0608292272780346, 'min_samples_split': 4.616628843965712}}
# Iteration 16:
# 	{'target': 0.7866884574292446, 'params': {'max_depth': 1.7200019606186996, 'min_samples_leaf': 4.698183175837189, 'min_samples_split': 2.68527243413613}}
# Iteration 17:
# 	{'target': 0.7869964893176169, 'params': {'max_depth': 2.7015497550129197, 'min_samples_leaf': 4.165555544482856, 'min_samples_split': 3.0863957421030976}}
# Iteration 18:
# 	{'target': 0.789073105270768, 'params': {'max_depth': 2.655395053973378, 'min_samples_leaf': 1.0071201340081635, 'min_samples_split': 1.3681267599285407}}
# Iteration 19:
# 	{'target': 0.7872683796429245, 'params': {'max_depth': 3.830483630963599, 'min_samples_leaf': 3.616484527858334, 'min_samples_split': 3.777680249432706}}
# Iteration 20:
# 	{'target': 0.7866884574292446, 'params': {'max_depth': 1.0456740999826053, 'min_samples_leaf': 1.0896254582036615, 'min_samples_split': 1.0577437227216406}}
# Iteration 21:
# 	{'target': 0.7866884574292446, 'params': {'max_depth': 1.0612200867199069, 'min_samples_leaf': 1.134829620386866, 'min_samples_split': 1.1364311191301761}}
# Iteration 22:
# 	{'target': 0.7865538994483636, 'params': {'max_depth': 4.9457004575378045, 'min_samples_leaf': 1.02840525506498, 'min_samples_split': 4.962770495069772}}
# Iteration 23:
# 	{'target': 0.7866884574292446, 'params': {'max_depth': 1.1843537338527452, 'min_samples_leaf': 1.0030196456570892, 'min_samples_split': 1.3052643392294245}}
# Iteration 24:
# 	{'target': 0.7866884574292446, 'params': {'max_depth': 1.1313056563464226, 'min_samples_leaf': 5.747698267145489, 'min_samples_split': 1.3297893232040008}}
# Iteration 25:
# 	{'target': 0.7870552022938342, 'params': {'max_depth': 4.956264003827238, 'min_samples_leaf': 5.986501619545959, 'min_samples_split': 3.8351118669478854}}
# Iteration 26:
# 	{'target': 0.7870552022938342, 'params': {'max_depth': 4.9832303432958085, 'min_samples_leaf': 5.77036495135829, 'min_samples_split': 1.4593808695017627}}
# Iteration 27:
# 	{'target': 0.7865538994483636, 'params': {'max_depth': 4.679957608078087, 'min_samples_leaf': 1.2787312250345182, 'min_samples_split': 4.968158944350646}}
# Iteration 28:
# 	{'target': 0.7866884574292446, 'params': {'max_depth': 1.1437723121416628, 'min_samples_leaf': 1.1899644986568911, 'min_samples_split': 4.5495010666919535}}
# Iteration 29:
# 	{'target': 0.7866884574292446, 'params': {'max_depth': 1.1558393895475105, 'min_samples_leaf': 5.916183106328923, 'min_samples_split': 1.0911401807429546}}
# Iteration 30:
# 	{'target': 0.7866884574292446, 'params': {'max_depth': 1.7224609068708499, 'min_samples_leaf': 1.169233429942122, 'min_samples_split': 1.0466383787202047}}
# Iteration 31:
# 	{'target': 0.7866884574292446, 'params': {'max_depth': 1.1342152767356564, 'min_samples_leaf': 5.598361439543124, 'min_samples_split': 1.1498667549733885}}
# Iteration 32:
# 	{'target': 0.7866884574292446, 'params': {'max_depth': 1.0596221896368976, 'min_samples_leaf': 1.136852769996432, 'min_samples_split': 4.707277967939948}}
# Iteration 33:
# 	{'target': 0.7864554409163802, 'params': {'max_depth': 4.510689488695651, 'min_samples_leaf': 1.185997101321567, 'min_samples_split': 1.6949539289109647}}
# Iteration 34:
# 	{'target': 0.7864231614647167, 'params': {'max_depth': 4.96855273460829, 'min_samples_leaf': 1.3656121463656472, 'min_samples_split': 1.03738529218844}}
# Iteration 35:
# 	{'target': 0.7870552022938342, 'params': {'max_depth': 4.9280285846122425, 'min_samples_leaf': 5.965593003500744, 'min_samples_split': 4.695331940183031}}
# Iteration 36:
# 	{'target': 0.7866884574292446, 'params': {'max_depth': 1.1557461427204812, 'min_samples_leaf': 2.1339031244256974, 'min_samples_split': 4.959595697578848}}
# Iteration 37:
# 	{'target': 0.7870552022938342, 'params': {'max_depth': 4.981314398946562, 'min_samples_leaf': 5.494237018262459, 'min_samples_split': 4.968694165903145}}
# Iteration 38:
# 	{'target': 0.7870552022938342, 'params': {'max_depth': 4.4375873845688885, 'min_samples_leaf': 5.877673156579034, 'min_samples_split': 1.9697269804016262}}
# Iteration 39:
# 	{'target': 0.7866884574292446, 'params': {'max_depth': 1.5900120054832012, 'min_samples_leaf': 1.567555156733348, 'min_samples_split': 4.703348663671068}}
# Iteration 40:
# 	{'target': 0.7865296761152937, 'params': {'max_depth': 4.720499521682894, 'min_samples_leaf': 1.0675220864304487, 'min_samples_split': 2.630122306179569}}
# Iteration 41:
# 	{'target': 0.7869964893176169, 'params': {'max_depth': 2.5556788104235255, 'min_samples_leaf': 5.087284102909869, 'min_samples_split': 1.0371761733774176}}
# Iteration 42:
# 	{'target': 0.7865538994483636, 'params': {'max_depth': 4.470156929029991, 'min_samples_leaf': 1.4742186716017414, 'min_samples_split': 4.051673502449546}}
# Iteration 43:
# 	{'target': 0.7866884574292446, 'params': {'max_depth': 1.0828866977605123, 'min_samples_leaf': 5.828232601952019, 'min_samples_split': 1.4603333404619816}}
# Iteration 44:
# 	{'target': 0.7866884574292446, 'params': {'max_depth': 1.851898746821366, 'min_samples_leaf': 1.3257632340335055, 'min_samples_split': 4.757650536754735}}
# Iteration 45:
# 	{'target': 0.789073105270768, 'params': {'max_depth': 2.3440304191924533, 'min_samples_leaf': 1.355074507777286, 'min_samples_split': 3.920314172210929}}
# Iteration 46:
# 	{'target': 0.7866884574292446, 'params': {'max_depth': 1.3319314302546503, 'min_samples_leaf': 5.735039504372616, 'min_samples_split': 4.752081032664071}}
# Iteration 47:
# 	{'target': 0.7870552022938342, 'params': {'max_depth': 4.335702260341337, 'min_samples_leaf': 5.850987681712739, 'min_samples_split': 4.303632327405772}}
# Iteration 48:
# 	{'target': 0.7864231614647167, 'params': {'max_depth': 4.002244411341797, 'min_samples_leaf': 1.4384440234838678, 'min_samples_split': 1.5149943077163786}}
# Iteration 49:
# 	{'target': 0.7864889225139261, 'params': {'max_depth': 4.0113101046125825, 'min_samples_leaf': 1.1603770376154439, 'min_samples_split': 3.2441158047258947}}

# %%
# TODO: 在测试数据上预测，并打印在测试集上的结果
best_min_samples_split = new_optimizer.max['params']['min_samples_split']
best_min_samples_leaf = new_optimizer.max['params']['min_samples_leaf']
best_max_depth = new_optimizer.max['params']['max_depth']

best_min_samples_split = int(best_min_samples_split)*5
best_min_samples_leaf = int(best_min_samples_leaf)*2
best_max_depth = int(best_max_depth)*2+2

model = DecisionTreeClassifier(min_samples_split=best_min_samples_split, min_samples_leaf=best_min_samples_leaf, max_depth=best_max_depth)
model.fit(X_train, y_train)
predictions = model.predict(X_test)

print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.98      0.91     66743
#            1       0.54      0.11      0.18     13257
#
#     accuracy                           0.84     80000
#    macro avg       0.70      0.55      0.55     80000
# weighted avg       0.80      0.84      0.79     80000

# %% [markdown]
# ### 5.4 使用XGBoost做分类（选做部分, 不计为分数）
# 还有一类算法叫做XGBoost, 这是目前工业界和各类比赛最常用的算法之一。 我们会在PART3里做详细的讲解，但感兴趣的朋友可以尝试一下。 它是一种集成式的方法，相当于多位专家共同去决策，所以模型既稳定效果也不错。这个模型也需要单独安装，具体安装请见： https://pypi.org/project/xgboost/  在linux和mac os上安装起来比较简单，但windows上可能会有各种问题出现，如在windows上使用，请参考： https://xgboost.readthedocs.io/en/latest/build.html

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
# TODO: 训练XGBoost模型  提示： 使用XGBClassifier。 至于超参数，可以试着去看一下官方文档，然后多尝试尝试。 
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=1)

# no mood to tune parameters, used the default ones
clf = XGBClassifier()
clf.fit(X_train, y_train, eval_metric='auc', verbose=True, eval_set=[(X_val, y_val)], early_stopping_rounds=100)

# TODO: 在测试数据上预测，并打印在测试集上的结果

y_pred = clf.predict(X_test)
y_pro = clf.predict_proba(X_test)[:, 1]
print(classification_report(y_test, predictions))
# Out:
# [0]	validation_0-auc:0.671321
# Will train until validation_0-auc hasn't improved in 100 rounds.
# [1]	validation_0-auc:0.67258
# [2]	validation_0-auc:0.672554
# [3]	validation_0-auc:0.673333
# [4]	validation_0-auc:0.674152
# [5]	validation_0-auc:0.674142
# [6]	validation_0-auc:0.674945
# [7]	validation_0-auc:0.674568
# [8]	validation_0-auc:0.678188
# [9]	validation_0-auc:0.68187
# [10]	validation_0-auc:0.681862
# [11]	validation_0-auc:0.682404
# [12]	validation_0-auc:0.682529
# [13]	validation_0-auc:0.689094
# [14]	validation_0-auc:0.690276
# [15]	validation_0-auc:0.690494
# [16]	validation_0-auc:0.691691
# [17]	validation_0-auc:0.693619
# [18]	validation_0-auc:0.694115

# %% [markdown]
# 恭喜你，完成第二次作业。 希望通过完成此作业，对建模有更深入的理解。 特别是对于数据的理解、特征选择以及超参数的选择等技术点。
